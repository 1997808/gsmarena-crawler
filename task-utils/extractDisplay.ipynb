# %%
import pandas as pd
import os
import numpy as np
import re
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Load data

# %%
data = pd.read_csv(os.path.join('..', 'data', 'Devices_Specs.csv'))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12513 entries, 0 to 12512
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Brand                  12513 non-null  object
#  1   url                    12513 non-null  object
#  2   imgUrl                 12513 non-null  object
#  3   Name                   12513 non-null  object
#  4   NETWORK_Technology     12513 non-null  object
#  5   NETWORK_2G_bands       12513 non-null  object
#  6   NETWORK_3G_bands       8678 non-null   object
#  7   NETWORK_4G_bands       5285 non-null   object
#  8   NETWORK_5G_bands       1087 non-null   object
#  9   NETWORK_GPRS           4178 non-null   object
#  10  NETWORK_EDGE           4185 non-null   object
#  11  NETWORK_Speed          8643 non-null   object
#  12  LAUNCH_Announced       12501 non-null  object
#  13  LAUNCH_Status          12513 non-null  object
#  14  BODY_Dimensions        12492 non-null  object
#  15  BODY_Weight            12422 non-null  object
#  16  BODY_Build             2384 non-null   object
#  17  BODY_SIM               12512 non-null  object
#  18  DISPLAY_Type           12509 non-null  object
#  19  DISPLAY_Size           11306 non-null  object
#  20  DISPLAY_Resolution     12466 non-null  object
#  21  DISPLAY_Protection     2689 non-null   object
#  22  PLATFORM_OS            8741 non-null   object
#  23  PLATFORM_Chipset       7321 non-null   object
#  24  PLATFORM_CPU           8570 non-null   object
#  25  PLATFORM_GPU           7192 non-null   object
#  26  MEMORY_Card_slot       12513 non-null  object
#  27  MEMORY_Internal        10721 non-null  object
#  28  MAIN_CAM_1_Module      12513 non-null  int64
#  29  MAIN_CAM_1_Features    7698 non-null   object
#  30  MAIN_CAM_1_Video       11067 non-null  object
#  31  SELFIE_CAM_2_Module    12513 non-null  int64
#  32  SELFIE_CAM_2_Features  2340 non-null   object
#  33  SELFIE_CAM_2_Video     3789 non-null   object
#  34  SOUND_Loudspeaker      12513 non-null  object
#  35  SOUND_35mm_jack        12445 non-null  object
#  36  COMMS_WLAN             12505 non-null  object
#  37  COMMS_Bluetooth        12511 non-null  object
#  38  COMMS_GPS              12473 non-null  object
#  39  COMMS_NFC              7706 non-null   object
#  40  COMMS_Radio            12444 non-null  object
#  41  COMMS_USB              11609 non-null  object
#  42  FEATURES_Sensors       8393 non-null   object
#  43  BATTERY_Type           12504 non-null  object
#  44  BATTERY_Stand_by       6785 non-null   object
#  45  BATTERY_Talk_time      7141 non-null   object
#  46  BATTERY_Music_play     734 non-null    object
#  47  MISC_Colors            11905 non-null  object
#  48  MISC_SAR               2566 non-null   object
#  49  MISC_SAR_EU            2807 non-null   object
#  50  MISC_Models            3837 non-null   object
#  51  MISC_Price             8439 non-null   object
# dtypes: int64(2), object(50)
# memory usage: 5.0+ MB

# %%
def inspect_data(data):
    dataCols = data.columns
    NullSum = data.isnull().sum()
    UniqueSum = data.nunique()
    ColType = data.dtypes
    # nsamples = 5
    # Samples = [', '.join([str(data[col][i]) for i in range(nsamples)]) for col in data.columns]
    n_UniqueSample = 5
    UniqueSamples = [', '.join([str(data[col].unique()[i]) for i in range(n_UniqueSample if len(
        data[col].unique()) > n_UniqueSample else len(data[col].unique()))]) for col in data.columns]

    Inspec = pd.DataFrame({'Column': dataCols, 'NullSum': NullSum,
                          'UniqueSum': UniqueSum, 'Type': ColType, 'Unique Sample': UniqueSamples})
    Inspec.index = [i for i in range(1, len(data.columns)+1)]
    return Inspec

# %%
# Lay cac cot thuoc DISPLAY
displayCols = [col for col in data.columns if re.search('DISPLAY', col)]

# inspect data cac cot thuoc DISPLAY
displayData = data[displayCols]
inspect_data(displayData)
# Out:
#                Column  NullSum  UniqueSum    Type  \
# 1        DISPLAY_Type        4        793  object
# 2        DISPLAY_Size     1207       5273  object
# 3  DISPLAY_Resolution       47       1409  object
# 4  DISPLAY_Protection     9824         98  object
#
#                                                                                                                                                                                                                                                             Unique Sample
# 1                                                                                                                                                                                                                 IPS LCD, Super AMOLED, AMOLED, LED-backlit IPS LCD, TFT
# 2  9.7 inches, 291.4 cm2 (~71.0% screen-to-body ratio), 7.0 inches, 135.1 cm2 (~69.8% screen-to-body ratio), 5.5 inches, 83.4 cm2 (~71.7% screen-to-body ratio), 5.0 inches, 68.9 cm2 (~65.3% screen-to-body ratio), 10.1 inches, 295.8 cm2 (~68.4% screen-to-body ratio)
# 3             1536 x 2048 pixels, 4:3 ratio (~264 ppi density), 720 x 1280 pixels, 16:9 ratio (~210 ppi density), 1080 x 1920 pixels, 16:9 ratio (~401 ppi density), 720 x 1280 pixels, 16:9 ratio (~294 ppi density), 1920 x 1200 pixels, 16:10 ratio (~224 ppi density)
# 4                                                                                                                         nan, Corning Gorilla Glass 4, Corning Gorilla Glass (unspecified version), Corning Gorilla Glass 4, oleophobic coating, Corning Gorilla Glass 3

# %% [markdown]
# # Type col

# %% [markdown]
# ## Null

# %%
# dem so luong null cua cac cot thuoc DISPLAY_Type
displayData['DISPLAY_Type'].isnull().sum()
# Out:
# 4

# %%
# Hien thi cac dong co DISPLAY_Type la null
data[displayData['DISPLAY_Type'].isnull()]
# Out:
#           Brand                                              url  \
# 6031   Motorola  https://www.gsmarena.com/motorola_v560-1057.php
# 9681      Sendo       https://www.gsmarena.com/sendo_s1-1066.php
# 10823     Vertu  https://www.gsmarena.com/vertu_diamond-1541.php
# 10824     Vertu   https://www.gsmarena.com/vertu_ascent-1219.php
#
#                                                       imgUrl           Name  \
# 6031          https://fdn2.gsmarena.com/vv/bigpic/mov560.gif  Motorola V560
# 9681            https://fdn2.gsmarena.com/vv/bigpic/ses1.gif       Sendo S1
# 10823  https://fdn2.gsmarena.com/vv/bigpic/vertu_diamond.gif  Vertu Diamond
# 10824   https://fdn2.gsmarena.com/vv/bigpic/vertu_ascent.gif   Vertu Ascent
#
#       NETWORK_Technology              NETWORK_2G_bands NETWORK_3G_bands  \
# 6031                 GSM  GSM 850 / 900 / 1800 / 1900               NaN
# 9681                 GSM               GSM 900 / 1800               NaN
# 10823                GSM        GSM 900 / 1800 / 1900               NaN
# 10824                GSM        GSM 900 / 1800 / 1900               NaN
#
#       NETWORK_4G_bands NETWORK_5G_bands NETWORK_GPRS NETWORK_EDGE  \
# 6031               NaN              NaN     Class 10           No
# 9681               NaN              NaN          Yes           No
# 10823              NaN              NaN           No           No
# 10824              NaN              NaN          Yes           No
#
#       NETWORK_Speed LAUNCH_Announced LAUNCH_Status  \
# 6031            NaN         2005, Q1     Cancelled
# 9681            NaN         2005, Q1     Cancelled
# 10823           NaN             2005  Discontinued
# 10824           NaN             2004  Discontinued
#
#                                          BODY_Dimensions      BODY_Weight  \
# 6031                                                 NaN              NaN
# 9681                                                 NaN   83 g (2.93 oz)
# 10823  122 x 42 x 15.5 mm, 78 cc (4.80 x 1.65 x 0.61 in)              NaN
# 10824    108 x 44 x 22 mm, 78 cc (4.25 x 1.73 x 0.87 in)  173 g (6.10 oz)
#
#       BODY_Build  BODY_SIM DISPLAY_Type DISPLAY_Size  \
# 6031         NaN  Mini-SIM          NaN          NaN
# 9681         NaN  Mini-SIM          NaN          NaN
# 10823        NaN  Mini-SIM          NaN          NaN
# 10824        NaN  Mini-SIM          NaN          NaN
#
#               DISPLAY_Resolution       DISPLAY_Protection PLATFORM_OS  \
# 6031                         NaN                      NaN         NaN
# 9681   96 x 64 pixels, 3:2 ratio                      NaN         NaN
# 10823                        NaN  Scratch-resistant glass         NaN
# 10824           116 x 148 pixels  Scratch-resistant glass         NaN
#
#       PLATFORM_Chipset PLATFORM_CPU PLATFORM_GPU MEMORY_Card_slot  \
# 6031               NaN          NaN          NaN               No
# 9681               NaN          NaN          NaN               No
# 10823              NaN          NaN          NaN               No
# 10824              NaN          NaN          NaN               No
#
#       MEMORY_Internal  MAIN_CAM_1_Module MAIN_CAM_1_Features MAIN_CAM_1_Video  \
# 6031              5MB                  1                 NaN               No
# 9681              NaN                  0                 NaN              NaN
# 10823             NaN                  0                 NaN              NaN
# 10824             NaN                  0                 NaN              NaN
#
#        SELFIE_CAM_2_Module SELFIE_CAM_2_Features SELFIE_CAM_2_Video  \
# 6031                     0                   NaN                NaN
# 9681                     0                   NaN                NaN
# 10823                    0                   NaN                NaN
# 10824                    0                   NaN                NaN
#
#       SOUND_Loudspeaker SOUND_35mm_jack COMMS_WLAN COMMS_Bluetooth COMMS_GPS  \
# 6031                Yes              No         No             1.1        No
# 9681                 No              No         No              No        No
# 10823               Yes              No         No              No        No
# 10824               Yes              No         No             Yes        No
#
#       COMMS_NFC COMMS_Radio    COMMS_USB FEATURES_Sensors  \
# 6031        NaN          No          NaN              NaN
# 9681        NaN          No          NaN              NaN
# 10823       NaN          No  Proprietary              NaN
# 10824       NaN          No          NaN              NaN
#
#                            BATTERY_Type BATTERY_Stand_by BATTERY_Talk_time  \
# 6031           Removable Li-Ion battery              NaN               NaN
# 9681           Removable Li-Ion battery      Up to 425 h         Up to 7 h
# 10823          Removable Li-Ion battery              NaN               NaN
# 10824  Removable Li-Ion 780 mAh battery      Up to 150 h         Up to 4 h
#
#       BATTERY_Music_play                           MISC_Colors MISC_SAR  \
# 6031                 NaN                                   NaN      NaN
# 9681                 NaN                                   NaN      NaN
# 10823                NaN  Yellow, Blue, Red, Black, Brown, Tan      NaN
# 10824                NaN  Yellow, Blue, Red, Black, Brown, Tan      NaN
#
#       MISC_SAR_EU MISC_Models      MISC_Price
# 6031          NaN         NaN             NaN
# 9681          NaN         NaN             NaN
# 10823         NaN         NaN  About 5160 EUR
# 10824         NaN         NaN  About 3320 EUR

# %%
def handleNull_Type(data: pd.DataFrame):
    data.loc[6031, 'DISPLAY_Type'] = 'TFT'
    data.loc[9681, 'DISPLAY_Type'] = 'TFT'
    data.loc[10823, 'DISPLAY_Type'] = 'TFT'
    data.loc[10824, 'DISPLAY_Type'] = 'Graphical, TFD'

# %%
handleNull_Type(data)
data['DISPLAY_Type'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Extract data

# %%
data['DISPLAY_Type'].value_counts()
# Out:
# IPS LCD                                                                                                         3530
# TFT, 256K colors                                                                                                1532
# TFT                                                                                                             1312
# TFT, 65K colors                                                                                                  866
# Super AMOLED                                                                                                     360
# CSTN, 65K colors                                                                                                 350
# AMOLED                                                                                                           277
# Monochrome graphic                                                                                               266
# TFT resistive touchscreen, 65K colors                                                                            242
# TFT resistive touchscreen, 256K colors                                                                           236
# TFT, 16M colors                                                                                                  142
# IPS LCD, 90Hz                                                                                                    135
# TFT LCD                                                                                                           85
# CSTN, 4096 colors                                                                                                 84
# IPS LCD, 120Hz                                                                                                    79
# PLS LCD                                                                                                           74
# STN, 65K colors                                                                                                   65
# IPS LCD, 400 nits (typ)                                                                                           63
# TFT,  256K colors                                                                                                 59
# Alphanumeric                                                                                                      51
# LCD                                                                                                               50
# OLED                                                                                                              47
# 65K colors                                                                                                        45
# TFT resistive touchscreen, 256K colors (65K effective)                                                            42
# UFB, 65K colors                                                                                                   41
# IPS LCD,                                                                                                          38
# LED-backlit LCD,                                                                                                  36
# IPS LCD, 480 nits (typ)                                                                                           33
# LED-backlit IPS LCD                                                                                               33
# S-LCD                                                                                                             30
# IPS LCD, HDR10                                                                                                    29
# Super AMOLED Plus                                                                                                 27
# TFT resistive touchscreen, 16M colors                                                                             26
# Super AMOLED, HDR10                                                                                               25
# IPS LCD, 450 nits (typ)                                                                                           25
# Super LCD3                                                                                                        25
# Grayscale graphic, 4 shades                                                                                       24
# TFT LCD, 256K colors                                                                                              24
# Super LCD2                                                                                                        23
# IPS LCD, 256K colors                                                                                              23
# OLED, HDR10                                                                                                       21
# CSTN, 256 colors                                                                                                  20
# IPS LCD, 90Hz, 480 nits (typ)                                                                                     19
# Super LCD                                                                                                         17
# AMOLED, 120Hz, HDR10+, 1300 nits (peak)                                                                           17
# S-IPS LCD                                                                                                         17
# TFT LCD, 65K colors                                                                                               16
# IPS LCD, 90Hz, 480 nits (typ), 600 nits (HBM)                                                                     16
# TFT, 260K colors                                                                                                  16
# AMOLED, 90Hz, HDR10+                                                                                              16
# Retina LTPO OLED, 1000 nits (peak)                                                                                15
# Monochrome graphic, Optimax                                                                                       15
# STN, monochrome graphics                                                                                          14
# TFT, 65k colors                                                                                                   14
# TFT resistive touchscreen                                                                                         14
# Grayscale graphic                                                                                                 14
# AMOLED, 120Hz, HDR10+                                                                                             13
# HD-IPS LCD                                                                                                        13
# IPS LCD, 90Hz, 400 nits (typ)                                                                                     13
# P-OLED                                                                                                            13
# Monochrome graphics                                                                                               13
# IPS LCD, 120Hz, HDR10                                                                                             13
# IGZO IPS LCD                                                                                                      13
# STN, 4096 colors                                                                                                  12
# TN                                                                                                                12
# AMOLED, HDR10                                                                                                     12
# STN, 256 colors                                                                                                   11
# TFT LCD, 90Hz                                                                                                     11
# TFT, 4096 colors                                                                                                  11
# Super clear LCD                                                                                                   11
# AMOLED, 120Hz                                                                                                     11
# True HD-IPS + LCD                                                                                                 10
# AMOLED, 256K colors                                                                                               10
# Fluid AMOLED, 90Hz, HDR10+                                                                                        10
# IPS LCD, 500 nits (peak)                                                                                          10
# LCD, 256K colors                                                                                                  10
# OLED, 65K colors                                                                                                  10
# Super IPS+ LCD                                                                                                     9
# TFD, 65K colors                                                                                                    9
# PLS LCD, 90Hz                                                                                                      9
# TN TFT                                                                                                             9
# TFD, 256K colors                                                                                                   9
# AMOLED, 430 nits (typ)                                                                                             9
# AMOLED, 1B colors, 120Hz, HDR10+, 1300 nits (peak)                                                                 9
# AMOLED, 65K colors                                                                                                 9
# Retina OLED, 1000 nits (peak)                                                                                      9
# AMOLED, 1B colors, 120Hz, HDR10+                                                                                   8
# Retina OLED, 450 nits (peak)                                                                                       8
# IPS LCD, 480 nits (peak)                                                                                           8
# AMOLED, 430 nits (typ), 800 nits (peak)                                                                            8
# OLED, 1B colors, 90Hz                                                                                              8
# IPS-NEO LCD                                                                                                        8
# OLED, 256K colors                                                                                                  8
# Super AMOLED Advanced                                                                                              8
# TFT LCD, 120Hz                                                                                                     8
# Super Retina XDR OLED, HDR10, Dolby Vision, 800 nits (HBM), 1200 nits (peak)                                       8
# Dynamic AMOLED, HDR10+                                                                                             8
# OLED, 1B colors, 120Hz                                                                                             8
# True HD-IPS LCD                                                                                                    7
# 3D LCD                                                                                                             7
# TFT LCD, 16M colors                                                                                                7
# AMOLED, 90Hz                                                                                                       7
# AMOLED, 430 nits (typ), 600 nits (HBM)                                                                             7
# Super AMOLED, 120Hz, HDR10+                                                                                        7
# LTPO OLED, 1B colors, 120Hz                                                                                        7
# 4096 colors                                                                                                        7
# OLED, 1B colors, HDR10, 120Hz                                                                                      7
# Optic AMOLED                                                                                                       7
# TFT, 256K colors (65K effective)                                                                                   7
# AMOLED, 1B colors, 120Hz, HDR10+, 500 nits (typ), 800 nits (HBM), 950 nits (peak)                                  7
# OLED, HDR10, 90Hz                                                                                                  7
# Super AMOLED, 430 nits (typ), 800 nits (peak)                                                                      7
# OLED, 16M colors                                                                                                   7
# Super AMOLED, 420 nits (peak)                                                                                      7
# TN TFT LCD                                                                                                         7
# AMOLED, 90Hz, HDR10+, 1300 nits (peak)                                                                             7
# Monochrome                                                                                                         7
# IPS LCD, 500 nits                                                                                                  7
# OLED, 1B colors, 120Hz, HDR BT.2020                                                                                6
# Grayscale graphics, 4 shades                                                                                       6
# IPS LCD, 500 nits (typ)                                                                                            6
# LTPO AMOLED                                                                                                        6
# AMOLED, 1B colors, 165Hz, HDR10+, 800 nits (typ), 1200 nits (peak)                                                 6
# Color graphic                                                                                                      6
# Retina IPS LCD, 625 nits (typ)                                                                                     6
# Super IPS+ LCD,                                                                                                    6
# IPS+ LCD                                                                                                           6
# IPS LCD, 120Hz, 550 nits (typ), 680 nits (HBM)                                                                     6
# OLED, 1B colors, 120Hz, HDR10+                                                                                     6
# IPS LCD, 120Hz, HDR10, 450 nits (typ)                                                                              6
# AMOLED, 90Hz, HDR10+, 500 nits (typ)                                                                               6
# Super AMOLED, 120Hz, 700 nits, 1200 nits (peak)                                                                    6
# TFT, 2.6M colors                                                                                                   6
# Dynamic AMOLED 2X, 120Hz, HDR10+                                                                                   6
# Super AMOLED, HDR                                                                                                  6
# OLED, 1B colors, 144Hz, HDR10+                                                                                     6
# IPS LCD, 480 nits                                                                                                  6
# Super AMOLED, 120Hz, HDR10+, 1300 nits (peak)                                                                      6
# IPS LCD, 90Hz, 500 nits (peak)                                                                                     6
# Super IPS LCD2                                                                                                     5
# Super AMOLED, 120Hz, 1000 nits (peak)                                                                              5
# Dynamic AMOLED 2X, 120Hz, HDR10+, 1200 nits (peak)                                                                 5
# TFT, 56K colors                                                                                                    5
# AMOLED, 1B colors, 120Hz, HDR10+, 1500 nits (peak)                                                                 5
# IPS LCD, HDR10, 450 nits (typ)                                                                                     5
# AMOLED, 90Hz, 430 nits (typ), 600 nits (HBM), 800 nits (peak)                                                      5
# PLS                                                                                                                5
# AMOLED, 1B colors, 144Hz, HDR10+, 800 nits (typ), 1200 nits (peak)                                                 5
# Sapphire crystal glass                                                                                             5
# CSTN, mono                                                                                                         5
# TN LCD                                                                                                             5
# Foldable OLED, 1B colors, 120Hz                                                                                    5
# LCD, 65K colors                                                                                                    5
# LCD, 90Hz                                                                                                          5
# IPS LCD, 600 nits (peak)                                                                                           5
# P-OLED, HDR10                                                                                                      5
# Fluid AMOLED, 1B colors, 120Hz, HDR10+                                                                             5
# IPS LCD, 450 nits (peak)                                                                                           5
# CSTN, 256K colors                                                                                                  4
# IPS LCD, 90Hz, HDR10                                                                                               4
# IPS LCD, 120Hz, 580 nits (peak)                                                                                    4
# Liquid Retina IPS LCD, 500 nits (typ)                                                                              4
# LTPO Super Retina XDR OLED, 120Hz, HDR10, Dolby Vision, 1000 nits (typ), 2000 nits (HBM)                           4
# Super LCD5                                                                                                         4
# Super AMOLED, 144Hz, HDR10+, 1300 nits (peak)                                                                      4
# OLED, 1B colors, 120Hz, Dolby Vision, HDR10+, 500 nits (typ), 900 nits (HBM)                                       4
# IPS LCD, 480 nits (typ), 600 nits (HBM)                                                                            4
# Super AMOLED, 120Hz, HDR10+, 420 nits (typ), 1300 nits (peak)                                                      4
# AMOLED, 120Hz, 1300 nits (peak)                                                                                    4
# IPS LCD, 90Hz, HDR10, 460 nits (typ)                                                                               4
# Foldable Dynamic AMOLED, HDR10+                                                                                    4
# CSTN,  65K colors                                                                                                  4
# IPS LCD, 400 nits                                                                                                  4
# Super AMOLED, 90Hz, 800 nits (HBM)                                                                                 4
# IPS LCD, 350 nits                                                                                                  4
# Dynamic AMOLED 2X, 120Hz, HDR10+, 1300 nits (peak)                                                                 4
# FSTN, monochrome graphics                                                                                          4
# Foldable Dynamic AMOLED 2X, 120Hz, HDR10+, 1200 nits (peak)                                                        4
# Super AMOLED Plus, 120Hz                                                                                           4
# Super Clear LCD                                                                                                    4
# OLED, HDR                                                                                                          4
# IPS LCD, 450 nits                                                                                                  4
# Super AMOLED, 120Hz                                                                                                4
# AMOLED, 144Hz                                                                                                      4
# UBC, 65K colors                                                                                                    4
# LCD, 144Hz, HDR10                                                                                                  4
# Super AMOLED, 90Hz                                                                                                 4
# AMOLED, HDR10, 600 nits (typ)                                                                                      4
# IPS LCD, 90Hz, 400 nits (typ), 500 nits (HBM)                                                                      4
# OLED, 1B colors, HDR                                                                                               4
# IPS LCD, 440 nits (typ)                                                                                            4
# Super IPS LCD                                                                                                      4
# AMOLED resistive touchscreen, 256K colors                                                                          4
# AMOLED, 1B colors, 144Hz, HDR10+, 1400 nits (peak)                                                                 4
# Super AMOLED, 90Hz, 1000 nits (peak)                                                                               4
# Super AMOLED, HDR10+, 500 nits (typ)                                                                               3
# TDDI IPS LCD, 350 nits (typ)                                                                                       3
# AMOLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 1100 nits (peak)                                                  3
# OLED, 120Hz, Dolby Vision, HDR10+, 1200 nits (peak)                                                                3
# AMOLED, 144Hz, HDR10+, 1300 nits (peak)                                                                            3
# AMOLED, 1B colors, 120Hz                                                                                           3
# AMOLED, 1B colors, 144Hz, HDR10+                                                                                   3
# AMOLED, 90Hz, 700 nits, 1000 nits (peak)                                                                           3
# AMOLED, 1B colors (China only), 120Hz, 1300 nits (peak)                                                            3
# AMOLED, 1B colors, 144Hz, HDR10+, 1000 nits                                                                        3
# IPS LCD, 120Hz, 480 nits (typ), 600 (HBM)                                                                          3
# IPS LCD, 90Hz, 550 nits                                                                                            3
# OLED, 1B colors, 90Hz, HDR10+                                                                                      3
# Super AMOLED, 120Hz, 800 nits (HBM)                                                                                3
# Dynamic AMOLED 2X, 120Hz, HDR10+, 1200 nits (HBM), 1750 nits (peak)                                                3
# IPS LCD, 90Hz, 480 nits (typ), 600 nits                                                                            3
# SC-LCD                                                                                                             3
# IPS LCD, 120Hz, 600 nits (peak)                                                                                    3
# AMOLED resistive touchscreen, 16M colors                                                                           3
# CGS, 256K colors                                                                                                   3
# AMOLED, 1B colors, HDR10+, 120Hz, 950 nits (peak)                                                                  3
# IPS LCD, 90Hz, 560 nits (peak)                                                                                     3
# Graphics                                                                                                           3
# IPS LCD, 120Hz, 480 nits (typ)                                                                                     3
# IPS LCD, 90Hz, 480 nits (typ), 600 nits (peak)                                                                     3
# AMOLED, 120Hz, HDR10+, 500 nits (typ), 800 nits (HBM), 1300 nits (peak)                                            3
# OLED, HDR BT.2020                                                                                                  3
# IPS LCD, 90Hz, 450 nits (typ)                                                                                      3
# IPS LCD, 90Hz, 680 nits (peak)                                                                                     3
# Foldable LTPO AMOLED, 120Hz, HDR10+                                                                                3
# AMOLED, 650 nits (typ), 900 nits (peak)                                                                            3
# Fluid AMOLED, 120Hz, HDR10+                                                                                        3
# AMOLED, HDR                                                                                                        3
# IPS LCD, 90Hz, 500 nits (HBM)                                                                                      3
# Super AMOLED Plus, HDR10+                                                                                          3
# AMOLED, 16M colors                                                                                                 3
# LTPO4 AMOLED, 1B colors, 144Hz, HDR10+, 1800 nits (peak)                                                           3
# IPS LCD, 90Hz, 650 nits (peak)                                                                                     3
# AMOLED, 90Hz, 1300 nits (peak)                                                                                     3
# AMOLED, 120Hz, HDR10+, 1500 nits (peak)                                                                            3
# AMOLED resistive touchscreen, 16M colors (65K effective)                                                           3
# IPS LCD, 144Hz, HDR10                                                                                              3
# IPS LCD, 350 nits (typ)                                                                                            3
# IPS LCD, 90Hz, 720 nits (peak)                                                                                     3
# AMOLED, 1000 nits (peak)                                                                                           3
# AMOLED, 1B colors, 120Hz, 800 nits (HBM)                                                                           3
# IPS LCD, 300 nits (typ)                                                                                            3
# OLED, 1B colors, 120Hz, HDR10                                                                                      3
# OLED, 1B colors, HDR10, 90Hz                                                                                       3
# AMOLED, 600 nits (typ)                                                                                             3
# AMOLED, 1B colors, 120Hz, 900 nits (peak)                                                                          3
# CSTN resistive touchscreen, 65K colors                                                                             3
# IPS LCD, 120Hz, 500 nits                                                                                           3
# AMOLED, 500 nits (peak)                                                                                            3
# Super Retina OLED, HDR10, Dolby Vision, 625 nits (HBM)                                                             3
# Retina LTPO OLED, 2000 nits (peak)                                                                                 3
# IPS+ LCD,                                                                                                          3
# AMOLED, 1B colors, 120Hz, 1200 nits (peak)                                                                         3
# FSTN                                                                                                               3
# IPS LCD, 600 nits                                                                                                  3
# IPS                                                                                                                3
# IPS LCD, 144Hz                                                                                                     3
# IPS LCD, 540 nits (typ)                                                                                            3
# OLED, 90Hz, HDR10                                                                                                  3
# CSTN, Mono                                                                                                         3
# Monochrome resistive touchscreen                                                                                   3
# Super AMOLED+                                                                                                      3
# Fluid AMOLED, 1B colors, 120Hz, HDR10+, 1450 nits (peak)                                                           2
# IPS LCD, 120Hz, 550 nits (typ), 680 nits (peak)                                                                    2
# IPS LCD, 500 nits (HBM)                                                                                            2
# OLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 1400 nits (peak)                                                    2
# Foldable Dynamic AMOLED 2X, 120Hz, HDR10+                                                                          2
# TFT resistive touchscreen, 65k colors                                                                              2
# Super Retina XDR OLED, HDR10, Dolby Vision, 1000 nits (HBM), 2000 nits (peak)                                      2
# LTPO AMOLED, 120Hz, HDR10+                                                                                         2
# AMOLED, 1B colors, HDR10, 120Hz, 800 nits (peak)                                                                   2
# 3D S-LCD                                                                                                           2
# CSTN resistive touchscreen, 32K colors                                                                             2
# AMOLED, 1B colors, 144Hz, HDR10+, 650 nits (typ)                                                                   2
# Foldable P-OLED                                                                                                    2
# AMOLED, 500 nits (typ)                                                                                             2
# S-LCD2                                                                                                             2
# Super AMOLED, 430 nits (typ), 600 nits (peak)                                                                      2
# Super AMOLED, 90Hz, HDR10+                                                                                         2
# IPS LCD, 144Hz, HDR10, Dolby Vision, 650 nits (typ)                                                                2
# LTPO AMOLED, 1B colors, 120Hz, Dolby Vision, HDR10+, 1000 nits (HBM), 1500 nits (peak)                             2
# IPS LCD, 360 nits (typ)                                                                                            2
# LTPO2 AMOLED, 1B colors, 120Hz, Dolby Vision, HDR10+, 1000 nits (HBM), 1500 nits (peak)                            2
# Super LCD6                                                                                                         2
# OLED, 120Hz                                                                                                        2
# TFT, 256k colors                                                                                                   2
# OLED, 1B colors, Dolby Vision, HDR10+, 120Hz, 950 nits (peak)                                                      2
# Backlit full graphics                                                                                              2
# Super AMOLED, 120Hz, HDR10+, 1100 nits (peak)                                                                      2
# IPS LCD, 450 nits (typ), 560 nits (peak)                                                                           2
# AMOLED, 1B colors, Dolby Vision, HDR10+, 120Hz, 1000 nits (peak)                                                   2
# AMOLED, 144Hz, 1300 nits (peak)                                                                                    2
# TFT resistive touchscreen, 4096 colors                                                                             2
# Grayscale LCD                                                                                                      2
# NCVM IPS                                                                                                           2
# IPS LCD, 1B colors, 144Hz, HDR10, Dolby Vision, 550 nits                                                           2
# OLED, 1B colors, 120Hz, HDR, 1000 nits (peak)                                                                      2
# IPS LCD, 1B colors, 144Hz, HDR10, 600 nits                                                                         2
# Super AMOLED, 90Hz, HDR10+, 500 nits (typ), 800 nits (HDR), 1100 nits (peak)                                       2
# AMOLED, 90Hz, 430 nits (typ), 600 nits (HBM), 750 nits (peak)                                                      2
# AMOLED, 90Hz, HDR10+, 500 nits (typ), 800 nits (HDR), 1100 nits (peak)                                             2
# AMOLED, 90Hz, HDR10+, 500 nits (typ), 800 nits (HBM)                                                               2
# LTPO AMOLED, 1B colors, 120Hz, HDR10+, BT.2020, 500 nits (typ), 1300 nits (peak)                                   2
# IPS LCD, 120Hz, HDR10, 650 nits (typ)                                                                              2
# IPS LCD, 120Hz, 600 nits (typ)                                                                                     2
# Super Retina XDR OLED, HDR10, Dolby Vision, 625 nits (HBM), 1200 nits (peak)                                       2
# MVA                                                                                                                2
# LTPO OLED, 1B colors, 120Hz, HDR10+, 1800 nits (peak)                                                              2
# Dual TFT, 256K colors                                                                                              2
# AMOLED, 90Hz, 500 nits (typ)                                                                                       2
# AMOLED, 1B colors, 120Hz, HDR10+, 500 nits (typ), 1200 nits (peak)                                                 2
# AMOLED, 120Hz, HDR, 1500 nits (peak)                                                                               2
# Natural IPS Pro LCD                                                                                                2
# CSTN resistive touchscreen, 4096 colors                                                                            2
# Super Retina XDR OLED, 120Hz, HDR10, Dolby Vision, 1000 nits (HBM), 1200 nits (peak)                               2
# AMOLED, 90Hz, 430 nits (typ), 600 nits (HDR)                                                                       2
# LTPO OLED, 1B colors, 120Hz, HDR10+, 1000 nits (peak)                                                              2
# Liquid Retina IPS LCD, 120Hz, HDR10, Dolby Vision, 600 nits (typ)                                                  2
# AMOLED, 1B colors, 120Hz, 500 nits (typ), 800 nits (HBM), 950 nits (peak)                                          2
# Foldable LTPO AMOLED, 120Hz, HDR10+, 1200 nits (HBM), 1600 nits (peak)                                             2
# IPS LCD, 380 nits (typ)                                                                                            2
# P-OLED, 90Hz, HDR                                                                                                  2
# IPS LCD, 144Hz, 600 nits                                                                                           2
# OLED, 260K colors                                                                                                  2
# AMOLED, 1B colors, 165Hz, HDR10+, 1000 nits (HBM), 1500 nits (peak)                                                2
# Foldable OLED, 1B colors, 90Hz, HDR10+, 800 nits                                                                   2
# P-OLED, HDR                                                                                                        2
# IPS LCD, 90Hz, 600 nits                                                                                            2
# AMOLED, 68B colors, 144Hz, Dolby Vision, HDR10+, 1200 nits (HBM), 2600 nits (peak)                                 2
# Super AMOLED, HDR, 800 nits (typ)                                                                                  2
# AMOLED, 1B colors, 144Hz, HDR10, 1300 nits (peak)                                                                  2
# TFT LCD, 90Hz, 850 nits (peak)                                                                                     2
# AMOLED, 430 nits (typ), 600 nits (HDM), 800 nits (peak)                                                            2
# AMOLED, HDR10, 430 nits (typ)                                                                                      2
# Liquid Retina XDR mini-LED LCD, 120Hz, HDR10, Dolby Vision, 1000 nits (typ), 1600 nits (peak)                      2
# AMOLED, 68B colors, Dolby Vision, HDR10+, 120Hz, 500 nits (typ), 1000 nits (peak)                                  2
# Retina IPS LCD, 500 nits (typ)                                                                                     2
# IPS LCD, 90Hz, HDR10, 560 nits (HBM)                                                                               2
# TDDI IPS LCD, 400 nits (typ)                                                                                       2
# OLED, 1B colors, 144Hz, 500 nits (typ), 800 nits (HBM)                                                             2
# IPS LCD, 144Hz, HDR10+, 500 nits (typ), 650 nits (peak)                                                            2
# IPS LCD, HDR10, 120Hz, 450 nits (typ)                                                                              2
# Transparent, monochrome                                                                                            2
# TDDI                                                                                                               2
# Super AMOLED, 120Hz, HDR10+, 700 nits (typ)                                                                        2
# Super AMOLED, 430 nits (typ)                                                                                       2
# ASV                                                                                                                2
# Super AMOLED, 120Hz, HDR10, 450 nits (typ), 1200 nits (peak)                                                       2
# AMOLED, 144Hz, HDR10+                                                                                              2
# Super IPS+                                                                                                         2
# Super AMOLED Plus, 420 nits (peak)                                                                                 2
# TFT, 16M                                                                                                           2
# 3D                                                                                                                 2
# Super AMOLED, 256K colors                                                                                          2
# P-OLED, HDR10+                                                                                                     2
# TFT,  65K colors                                                                                                   2
# IPS LCD, 90Hz, 480 nits                                                                                            2
# TFT resistive touchscreen, 16M colors (65K effective)                                                              2
# Super AMOLED, HDR10+                                                                                               2
# True Full HD IPS Plus LCD                                                                                          2
# Super AMOLED, 90Hz, HDR10+, 500 nits (typ)                                                                         2
# S-PureLED                                                                                                          2
# Curved P-OLED                                                                                                      2
# IPS LCD, 120Hz, 500 nits (peak)                                                                                    2
# P-OLED, HDR10, Dolby Vision                                                                                        2
# AMOLED, 120Hz, HDR10+, 500 nits (typ)                                                                              2
# Dynamic AMOLED 2X, 120Hz, HDR10+, 1400 nits (peak)                                                                 2
# TFT , 65K colors                                                                                                   2
# FSTN, 4096 colors                                                                                                  2
# 4K colors                                                                                                          2
# AMOLED, HDR10+, 600 nits (typ)                                                                                     2
# TFT, 64K colors                                                                                                    2
# OLED, 1B colors, HDR BT.2020                                                                                       2
# AMOLED  (65K effective)                                                                                            2
# IPS LCD, 90Hz, 400 nits (peak)                                                                                     2
# Super AMOLED, 120Hz, HDR10+, 900 nits (HBM), 1300 nits (peak)                                                      2
# TFT  (65K effective)                                                                                               2
# IPS LCD, 470 nits (typ)                                                                                            2
# Foldable OLED, 90Hz                                                                                                2
# AMOLED, 1B colors, 165Hz, 630 nits (typ)                                                                           2
# Dual TFT                                                                                                           2
# IPS LCD, 1B colors, 120Hz, HDR10, Dolby Vision                                                                     2
# PLS LCD, 120Hz                                                                                                     2
# OLED, HDR10+, Dolby Vision, 120Hz, 420 nits (typ), 600 nits (peak)                                                 2
# IPS LCD, 320 nits (typ)                                                                                            2
# IPS LCD, HDR BT.2020                                                                                               2
# P-OLED, 1B colors, 144Hz, HDR10+                                                                                   2
# OLED, 1B colors, 165Hz, HDR10+, Dolby Vision, 1300 nits (peak)                                                     2
# IPS LCD, 330 nits (typ)                                                                                            2
# Dynamic AMOLED 2X, 120Hz, HDR10+, 1750 nits (peak)                                                                 2
# Super AMOLED, HDR, 430 nits (typ)                                                                                  2
# Super AMOLED, 90Hz, 600 nits (HDR)                                                                                 2
# Foldable OLED                                                                                                      2
# AMOLED, 165Hz, 700 nits (typ)                                                                                      2
# STN resistive touchscreen, 4096 colors                                                                             2
# AMOLED, 1B colors (China only), 120Hz, 600 nits                                                                    2
# Monochrome resistive touchscreen, 16 shades                                                                        2
# AMOLED, 120Hz, 700 nits (peak)                                                                                     2
# AMOLED, 1B colors (China only), 165Hz, 700 nits (typ)                                                              2
# AMOLED, 1B colors, 120Hz, HDR10, 1300 nits (peak)                                                                  1
# Foldable LTPO4 AMOLED, 120Hz, HDR10+, Dolby Vision, 1800 nits (peak)                                               1
# IPS LCD, 550 nits (typ)                                                                                            1
# IGZO OLED, 1B colors, 1300 nits (peak), 120Hz                                                                      1
# QVGA, 256K colors                                                                                                  1
# IGZO OLED, 1B colors, 1300 nits (peak)                                                                             1
# IGZO IPS LCD, 120Hz, HDR10                                                                                         1
# Liquid Retina IPS LCD, 625 nits (typ)                                                                              1
# IGZO IPS LCD, 1B colors, 120Hz, HDR10, Dolby Vision                                                                1
# AMOLED, 120Hz, HDR10+, 500 nits (typ), 1000 nits (HBM), 1300 nits (peak)                                           1
# IPS LCD, 120Hz, HDR10, 650 nits (HBM)                                                                              1
# ...
# P-OLED, 1B colors, 120Hz                                                                                           1
# OLED, 1B colors, 165Hz, HDR10+                                                                                     1
# P-OLED, 144Hz, HDR10+, 1200 nits (peak)                                                                            1
# Foldable LTPO AMOLED, 1B colors, 144Hz, HDR10+, 1400 nits (peak)                                                   1
# Foldable LTPO AMOLED, 1B colors, 165Hz, HDR10+, 1400 nits (peak)                                                   1
# P-OLED, 1B colors, 120Hz, 1300 nits (peak)                                                                         1
# P-OLED, 1B colors, 144Hz, HDR10+, 1300 nits (peak)                                                                 1
# P-OLED, 1B colors, 144Hz, HDR10+, 1200 nits (peak)                                                                 1
# OLED, 600 nits (typ)                                                                                               1
# AMOLED, 90Hz, HDR, 800 nits (peak)                                                                                 1
# STN, 256K colors                                                                                                   1
# IPS LCD, 440 nits (peak)                                                                                           1
# AMOLED, 550 nits (typ)                                                                                             1
# IPS LCD, 420 nits                                                                                                  1
# AMOLED, 450 nits (typ)                                                                                             1
# OLED, 1B colors, 120Hz, 500 nits (typ), 700 nits (peak)                                                            1
# TFT, 26K colors                                                                                                    1
# LTPO OLED, 120Hz, HDR10+, 500 nits (typ), 1800 nits (peak)                                                         1
# LTPO OLED, 1B colors, 120Hz, 600 nits (typ), 1800 nits (peak)                                                      1
# AMOLED, 1B colors, 120Hz, 950 nits (peak)                                                                          1
# TFD, 64K colors                                                                                                    1
# AMOLED, 1B colors, 144Hz, 950 nits (peak)                                                                          1
# AMOLED, 1B colors, 120Hz, HDR10+, 1100 nits (HBM), 1450 nits (peak)                                                1
# AMOLED, 90Hz, 430 nits (typ), 800 nits (peak)                                                                      1
# OLED, 256 colors                                                                                                   1
# Foldable LTPO AMOLED, 120Hz, HDR10+, 1200 nits (HBM), 1550 nits (peak)                                             1
# Super AMOLED, 120Hz, HDR10+, 1000 nits (HBM)                                                                       1
# Foldable OLED, 120Hz, HDR10+, 1000 nits (HBM), 1450 nits (peak)                                                    1
# Foldable Dynamic AMOLED 2X, 120Hz, HDR10+, 1750 nits (peak)                                                        1
# OLED, HDR, 90Hz                                                                                                    1
# LTPO AMOLED, 120Hz, HDR10+, 1000 nits (HBM), 1500 nits (peak)                                                      1
# Dynamic AMOLED 2X, 120Hz, HDR10+, 1450 nits (peak)                                                                 1
# IPS LCD, 90Hz, 400 nits                                                                                            1
# Super AMOLED, 90Hz, HDR10+, 1000 nits (peak)                                                                       1
# IPS LCD, 380 nits (peak)                                                                                           1
# Super AMOLED, 600 nits (peak)                                                                                      1
# IPS LCD, 480 nits (typ), 600 nits (peak)                                                                           1
# Super AMOLED, 450 nits (peak)                                                                                      1
# IPS LCD, 470 nits (typ), 570 nits (peak)                                                                           1
# IPS LCD, 120Hz , 480 nits (typ), 600 nits (peak)                                                                   1
# AMOLED, 90Hz, HDR10+, 1000 nits (HBM), 1400 nits (peak)                                                            1
# Super AMOLED, HDR10, 1000 nits (peak)                                                                              1
# Super AMOLED, 430 nits (typ), 1000 nits (peak)                                                                     1
# Super AMOLED, 90Hz, 1200 nits (peak)                                                                               1
# IPS LCD, 120Hz, 480 nits (typ), 600 nits (peak)                                                                    1
# IPS LCD, 90Hz, 580 nits (peak)                                                                                     1
# OLED, 90Hz, HDR10+                                                                                                 1
# Super AMOLED, 120Hz, 600 nits                                                                                      1
# IPS LCD, 480 nits (typ), 570 nits (peak)                                                                           1
# IPS LCD, 90Hz, 600 nits (peak)                                                                                     1
# IPS LCD, 420 nits (typ)                                                                                            1
# Super AMOLED, 120Hz, 1000 nits (HBM)                                                                               1
# OLED, 120Hz, HDR10+, 1400 nits (HBM), 2000 nits (peak)                                                             1
# PLS LCD, 90Hz, 400 nits (peak)                                                                                     1
# LCD, 550 nits (peak)                                                                                               1
# TFT resistive  touchscreen, 65K colors                                                                             1
# UFS, 65K colors                                                                                                    1
# TFD, 16M colors                                                                                                    1
# AMOLED  resistive touchscreen, 16M colors (65K effective colors)                                                   1
# TFT , 16M colors                                                                                                   1
# AMOLED 3D                                                                                                          1
# Virtual Colour                                                                                                     1
# Super Flexible AMOLED                                                                                              1
# a-Si AHVA                                                                                                          1
# IPS LCD, 360 nits                                                                                                  1
# IPS LCD, 390 nits (peak)                                                                                           1
# IPS LCD, 350 nits (peak)                                                                                           1
# LTPO OLED, 120Hz, HDR10+, 1600 nits (HBM), 2400 nits (peak)                                                        1
# IPS LCD, 320 nits (peak)                                                                                           1
# TFT LCD, 120Hz, HDR10+                                                                                             1
# TFT LCD, 60Hz (International), 90Hz (SM-A326U, SM-326DL only)                                                      1
# Dynamic AMOLED 2X, 120Hz, HDR10+, 1500 nits (peak)                                                                 1
# Super AMOLED, 120Hz, HDR10+, 800 nits (HBM)                                                                        1
# Dynamic AMOLED 2X, 120Hz, 1200 nits (peak)                                                                         1
# Super AMOLED, 90Hz, 600 nits                                                                                       1
# Foldable IPS LCD                                                                                                   1
# OLED, 90Hz, 880 nits (peak)                                                                                        1
# Super AMOLED Plus, 120Hz, 800 nits (HBM)                                                                           1
# PLS LCD, 90Hz, 400 nits (typ)                                                                                      1
# IPS LCD, 570 nits (HBM)                                                                                            1
# LTPO2 AMOLED, 1B colors, 120Hz, HDR10+, 500 nits (typ), 800 nits (HBM), 1400 nits (peak)                           1
# Super AMOLED, 90Hz, 430 nits (typ), 600 nits (HBM)                                                                 1
# Foldable LTPO AMOLED, 120Hz, HDR10+, 500 nits (typ), 800 nits (HBM), 1000 nits (peak)                              1
# AMOLED, 90Hz, 430 nits (typ), 600 nits (HDR), 750 nits (peak)                                                      1
# AMOLED, 90Hz, 430 nits (typ), 600 nits (peak)                                                                      1
# OLED, 1B colors, 120Hz, HDR10+, 1600 nits (peak)                                                                   1
# OLED, 90Hz, 600 nits (typ), 750 nits (peak)                                                                        1
# AMOLED, 90Hz, 430 nits (typ), 750 nits (peak)                                                                      1
# AMOLED, 90Hz, HDR10+, 500 nits (typ), 1100 nits (peak)                                                             1
# Super AMOLED, 90Hz, 430 nits (typ), 750 nits (peak)                                                                1
# AMOLED, 120Hz, HDR10, 430 nits (typ), 800 nits (peak)                                                              1
# IPS LCD, 480 nits (typ), 550 nits (peak)                                                                           1
# IPS LCD, 120Hz, 480 nits (typ), 600 nits (HBM)                                                                     1
# AMOLED, 90Hz, HDR10+, 500 nits (typ), 800 nits (HBM), 920 nits (peak)                                              1
# OLED, 430 nits (typ), 600 nits (HDR)                                                                               1
# AMOLED, 1B colors, 120Hz, HDR10+, 1600 nits (peak)                                                                 1
# AMOLED, 90Hz, HDR10+, 430 nits (typ), 600 nits (HBM), 800 nits (peak)                                              1
# IPS LCD, 120Hz, 480 nits                                                                                           1
# AMOLED, 90Hz, HDR10+, 430 nits (typ), 600 nits (HDR), 800 nits (peak)                                              1
# AMOLED, 1B colors, 120Hz, HDR10+, 500 nits (typ), 800 nits (HBM), 1000 nits (peak)                                 1
# LTPO2 AMOLED, 1B colors, 120Hz, HDR10+, BT.2020, 500 nits (typ), 800 nits (HBM), 1300 nits (peak)                  1
# AMOLED, 120Hz, 500 nits (typ), 800 nits (HBM), 1300 nits (peak)                                                    1
# IPS LCD, 1B colors, 360 nits (typ)                                                                                 1
# AMOLED, 1B colors, 120Hz, HDR10, 1400 nits (peak)                                                                  1
# IPS LCD, 1B colors, 144Hz, 600 nits                                                                                1
# OLED, 1B colors, 120Hz, 1000 nits (peak)                                                                           1
# OLED, 1B colors, 120Hz, 500 nits (typ), 800 nits (HBM), 950 nits (peak)                                            1
# AMOLED, 430 nits (typ), 600 nits (peak)                                                                            1
# Super AMOLED, 90Hz, HDR10, 500 nits (typ)                                                                          1
# IPS LCD, 144Hz, 480 nits (typ), 600 nits (HBM)                                                                     1
# Foldable LTPO OLED, 1B colors, 120Hz, HDR10+, Dolby Vision, IMAX Enhanced                                          1
# IPS LCD, 530 nits (peak)                                                                                           1
# Super AMOLED, 90Hz, 430 nits (typ), 1000 nits (peak)                                                               1
# IPS LCD, 90Hz, 600 nits (HBM)                                                                                      1
# CSTN                                                                                                               1
# -                                                                                                                  1
# IPS LCD, 120Hz, 600 nits (typ), 680 nits (peak)                                                                    1
# AMOLED, 1B colors, HDR10+, 120Hz, 800 nits                                                                         1
# OLED, 1B colors, 144Hz, 1400 nits (peak)                                                                           1
# IPS LCD, 90Hz, 450 nits (peak)                                                                                     1
# AMOLED, 1B colors, 144Hz, HDR10+, 500 nits (typ), 1100 nits (HBM), 1400 nits (peak)                                1
# IPS LCD, 1B colors, 120Hz, 450 nits (peak)                                                                         1
# Foldable OLED, 1B colors, 90Hz, 1600 nits (peak)                                                                   1
# OLED, 430 nits (typ)                                                                                               1
# IGZO IPS LCD, 120Hz, 380 nits (typ)                                                                                1
# IGZO IPS LCD, 120Hz, 580 nits (typ)                                                                                1
# TFT resistive resistive touchscreen, 4096 colors                                                                   1
# CSTN, Monochrome                                                                                                   1
# AMOLED, 56K colors                                                                                                 1
# Foldable LTPO OLED, 1B colors, 120Hz, HDR10+, IMAX Enhanced, 1600 nits (peak)                                      1
# TFT LCD, 1B colors, 144Hz, IMAX Enhanced, HDR10, 700 nits (HBM)                                                    1
# TFT,65K colors                                                                                                     1
# AMOLED, 90Hz, HDR10, 500 nits (typ)                                                                                1
# Super AMOLED, 500 nits (typ)                                                                                       1
# AMOLED, 1B colors, 120Hz, HDR, 1600 nits (peak)                                                                    1
# AMOLED or LCD, 256K colors                                                                                         1
# Name: DISPLAY_Type, dtype: int64

# %%
def unifyType(data: pd.DataFrame):
    # lowercase
    data['DISPLAY_Type'] = data['DISPLAY_Type'].str.lower()

    # TFT neu co chua các từ sau: 'tft'
    data.loc[data['DISPLAY_Type'].str.contains(
        'tft'), 'DISPLAY_Type'] = 'TFT'
    
    # TFD neu co chua các từ sau: 'tfd'
    data.loc[data['DISPLAY_Type'].str.contains(
        'tfd'), 'DISPLAY_Type'] = 'TFD'

    # IPS neu chua: ips
    data.loc[data['DISPLAY_Type'].str.contains(
        'ips') == True, 'DISPLAY_Type'] = 'IPS'
    
    # OLED neu chua: oled
    data.loc[data['DISPLAY_Type'].str.contains(
        'oled') == True, 'DISPLAY_Type'] = 'OLED'

    # CSTN neu chua: cstn
    data.loc[data['DISPLAY_Type'].str.contains(
        'cstn') == True, 'DISPLAY_Type'] = 'CSTN'
    
    # FSTN neu chua: fstn
    data.loc[data['DISPLAY_Type'].str.contains(
        'fstn') == True, 'DISPLAY_Type'] = 'FSTN'

    # STN neu chua: stn
    data.loc[data['DISPLAY_Type'].str.contains(
        'stn') == True, 'DISPLAY_Type'] = 'STN'

    # TN neu chua: tn
    data.loc[data['DISPLAY_Type'].str.contains(
        'tn') == True, 'DISPLAY_Type'] = 'TN'

    # PLS neu chua: pls
    data.loc[data['DISPLAY_Type'].str.contains(
        'pls') == True, 'DISPLAY_Type'] = 'PLS'
    
    # Alphanumeric neu chua: alphanumeric
    data.loc[data['DISPLAY_Type'].str.contains(
        'alphanumeric') == True, 'DISPLAY_Type'] = 'Alphanumeric'
    
    # Monochrome neu chua: monochrome
    data.loc[data['DISPLAY_Type'].str.contains(
        'monochrome') == True, 'DISPLAY_Type'] = 'Monochrome'

    # Grayscale neu chua: grayscale, greyscale
    data.loc[data['DISPLAY_Type'].str.contains(
        'grayscale|greyscale') == True, 'DISPLAY_Type'] = 'Grayscale'

    # Backlit neu chua: backlit
    data.loc[data['DISPLAY_Type'].str.contains(
        'backlit') == True, 'DISPLAY_Type'] = 'Backlit'
    
    # S-LCD neu chua: s-lcd, super lcd, super-lcd, superlcd
    data.loc[data['DISPLAY_Type'].str.contains(
        's-lcd|super lcd|super-lcd|superlcd') == True, 'DISPLAY_Type'] = 'S-LCD'
    
    # color neu chua: color
    data.loc[data['DISPLAY_Type'].str.contains(
        'color') == True, 'DISPLAY_Type'] = 'Color'
    
    # LCD neu chua: lcd, crystal,  mva, pureled
    data.loc[data['DISPLAY_Type'].str.contains(
        'lcd|crystal|mva|pureled') == True, 'DISPLAY_Type'] = 'LCD'
    
    # Con lai la 'Unknown'
    data['DISPLAY_Type'].replace([i for i in data['DISPLAY_Type'].unique() if i not in ['TFT', 'TFD', 'IPS', 'OLED', 'CSTN', 'FSTN', 'STN', 'TN', 'PLS', 'Alphanumeric', 'Monochrome', 'Grayscale', 'Backlit', 'S-LCD', 'Color', 'LCD']], 'Unknown', inplace=True)

# %%
dataTemp = data.copy()
uniqueType(dataTemp)
dataTemp['DISPLAY_Type'].value_counts()
# Out:
# TFT             4739
# IPS             4486
# OLED            1763
# CSTN             481
# Monochrome       310
# Color            132
# S-LCD            107
# STN              107
# LCD               99
# PLS               92
# Alphanumeric      51
# Grayscale         47
# Backlit           38
# TFD               22
# TN                17
# Unknown           13
# FSTN               9
# Name: DISPLAY_Type, dtype: int64

# %% [markdown]
# ## Extract func

# %%
def extract_display_type(data :pd.DataFrame, inplace :bool=False):
    if inplace == False:
        data = data.copy()
    
    handleNull_Type(data)
    unifyType(data) 
    return data

# %%
dataTemp = data.copy()
extract_display_type(dataTemp, inplace=True)
dataTemp['DISPLAY_Type'].value_counts()
# Out:
# TFT             4739
# IPS             4486
# OLED            1763
# CSTN             481
# Monochrome       310
# Color            132
# S-LCD            107
# STN              107
# LCD               99
# PLS               92
# Alphanumeric      51
# Grayscale         47
# Backlit           38
# TFD               22
# TN                17
# Unknown           13
# FSTN               9
# Name: DISPLAY_Type, dtype: int64

# %% [markdown]
# # Size col

# %% [markdown]
# ## Null

# %%
displayData['DISPLAY_Size'].isnull().sum()
# Out:
# 1207

# %% [markdown]
# -> Quá nhiều null, điền null bằng mode (do categorical khong the tinh mean voi median)

# %%
def handleNull_Size(data: pd.DataFrame):
    data['DISPLAY_Size'].fillna(data['DISPLAY_Size'].mode()[0], inplace=True)

# %%
dataTemp = data.copy()
handleNull_Size(dataTemp)
dataTemp['DISPLAY_Size'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Extract data

# %%
displayData['DISPLAY_Size'].value_counts()
# Out:
# 5.0 inches, 68.9 cm2                                                  41
# 5.0 inches, 68.9 cm2 (~65.8% screen-to-body ratio)                    33
# 5.0 inches, 68.9 cm2 (~66.0% screen-to-body ratio)                    33
# 5.0 inches, 68.9 cm2 (~66.7% screen-to-body ratio)                    32
# 5.0 inches, 68.9 cm2 (~66.2% screen-to-body ratio)                    30
# 4.0 inches, 45.5 cm2                                                  28
# 5.0 inches, 68.9 cm2 (~66.5% screen-to-body ratio)                    27
# 5.0 inches, 68.9 cm2 (~66.9% screen-to-body ratio)                    27
# 5.0 inches, 68.9 cm2 (~67.9% screen-to-body ratio)                    26
# 5.0 inches, 68.9 cm2 (~65.3% screen-to-body ratio)                    25
# 5.0 inches, 68.9 cm2 (~67.6% screen-to-body ratio)                    24
# 4.0 inches, 45.5 cm2 (~58.3% screen-to-body ratio)                    23
# 4.0 inches, 45.5 cm2 (~56.9% screen-to-body ratio)                    23
# 5.5 inches, 83.4 cm2 (~71.7% screen-to-body ratio)                    23
# 5.0 inches, 68.9 cm2 (~65.1% screen-to-body ratio)                    21
# 5.0 inches, 68.9 cm2 (~67.1% screen-to-body ratio)                    19
# 5.0 inches, 68.9 cm2 (~65.9% screen-to-body ratio)                    19
# 4.5 inches, 55.8 cm2 (~63.1% screen-to-body ratio)                    19
# 1.3 inches                                                            19
# 5.0 inches, 68.9 cm2 (~65.0% screen-to-body ratio)                    19
# 5.5 inches, 83.4 cm2                                                  18
# 6.5 inches, 102.0 cm2 (~81.6% screen-to-body ratio)                   18
# 5.0 inches, 68.9 cm2 (~67.7% screen-to-body ratio)                    18
# 1.39 inches                                                           18
# 5.0 inches, 68.9 cm2 (~69.8% screen-to-body ratio)                    18
# 5.0 inches, 68.9 cm2 (~68.1% screen-to-body ratio)                    18
# 6.51 inches, 102.3 cm2 (~81.6% screen-to-body ratio)                  18
# 5.5 inches, 83.4 cm2 (~72.2% screen-to-body ratio)                    18
# 5.5 inches, 83.4 cm2 (~70.6% screen-to-body ratio)                    17
# 5.0 inches, 68.9 cm2 (~68.4% screen-to-body ratio)                    17
# 2.4 inches, 17.8 cm2                                                  17
# 1.43 inches                                                           17
# 1.4 inches                                                            16
# 5.0 inches, 68.9 cm2 (~66.4% screen-to-body ratio)                    16
# 5.5 inches, 83.4 cm2 (~70.3% screen-to-body ratio)                    16
# 6.58 inches, 104.3 cm2 (~84.5% screen-to-body ratio)                  16
# , -                                                                   16
# 1.8 inches                                                            16
# 4.0 inches, 45.5 cm2 (~57.4% screen-to-body ratio)                    16
# 5.5 inches, 83.4 cm2 (~71.4% screen-to-body ratio)                    16
# 4.5 inches, 55.8 cm2 (~62.2% screen-to-body ratio)                    15
# 1.78 inches                                                           15
# 1.5 inches                                                            15
# 5.0 inches, 68.9 cm2 (~67.4% screen-to-body ratio)                    15
# 3.5 inches, 36.5 cm2                                                  15
# 5.5 inches, 83.4 cm2 (~70.8% screen-to-body ratio)                    15
# 5.5 inches, 83.4 cm2 (~71.3% screen-to-body ratio)                    15
# 1.8 inches, 10.2 cm2 (~21.9% screen-to-body ratio)                    15
# 6.5 inches, 102.0 cm2 (~81.7% screen-to-body ratio)                   14
# 4.5 inches, 55.8 cm2 (~61.7% screen-to-body ratio)                    14
# 1.2 inches                                                            14
# 5.5 inches, 83.4 cm2 (~69.0% screen-to-body ratio)                    14
# 6.5 inches, 102.0 cm2 (~83.9% screen-to-body ratio)                   14
# 2.0 inches, 12.6 cm2 (~24.1% screen-to-body ratio)                    14
# 1.5 inches, 7.3 cm2 (~15.7% screen-to-body ratio)                     14
# 5.0 inches, 68.9 cm2 (~68.9% screen-to-body ratio)                    14
# 5.0 inches, 68.9 cm2 (~66.8% screen-to-body ratio)                    14
# 5.0 inches, 68.9 cm2 (~67.2% screen-to-body ratio)                    13
# 5.0 inches, 68.9 cm2 (~64.7% screen-to-body ratio)                    13
# 5.0 inches, 68.9 cm2 (~68.8% screen-to-body ratio)                    13
# 5.0 inches, 68.9 cm2 (~66.6% screen-to-body ratio)                    13
# 5.0 inches, 68.9 cm2 (~63.8% screen-to-body ratio)                    13
# 5.0 inches, 68.9 cm2 (~65.6% screen-to-body ratio)                    13
# 2.4 inches, 17.8 cm2 (~25.4% screen-to-body ratio)                    13
# 5.5 inches, 83.4 cm2 (~72.7% screen-to-body ratio)                    13
# 4.0 inches, 45.5 cm2 (~59.4% screen-to-body ratio)                    13
# 5.0 inches, 68.9 cm2 (~68.3% screen-to-body ratio)                    13
# 5.0 inches, 68.9 cm2 (~66.3% screen-to-body ratio)                    12
# 4.0 inches, 45.5 cm2 (~56.1% screen-to-body ratio)                    12
# 5.0 inches, 68.9 cm2 (~69.3% screen-to-body ratio)                    12
# 5.0 inches, 68.9 cm2 (~64.2% screen-to-body ratio)                    12
# 4.5 inches, 55.8 cm2                                                  12
# 5.0 inches, 68.9 cm2 (~65.4% screen-to-body ratio)                    12
# 2.4 inches, 17.8 cm2 (~32.1% screen-to-body ratio)                    12
# 6.43 inches, 99.8 cm2 (~85.3% screen-to-body ratio)                   11
# 5.0 inches, 68.9 cm2 (~67.0% screen-to-body ratio)                    11
# 5.0 inches, 68.9 cm2 (~68.6% screen-to-body ratio)                    11
# 3.5 inches, 36.5 cm2 (~49.5% screen-to-body ratio)                    11
# 5.5 inches, 83.4 cm2 (~71.5% screen-to-body ratio)                    11
# 5.0 inches, 68.9 cm2 (~68.7% screen-to-body ratio)                    11
# 6.52 inches, 102.6 cm2 (~81.0% screen-to-body ratio)                  11
# 1.8 inches, 10.2 cm2 (~21.2% screen-to-body ratio)                    11
# 5.0 inches, 68.9 cm2 (~68.0% screen-to-body ratio)                    11
# 1.65 inches                                                           11
# 6.5 inches, 102.0 cm2 (~83.4% screen-to-body ratio)                   11
# 4.5 inches, 55.8 cm2 (~64.1% screen-to-body ratio)                    11
# 6.5 inches, 102.0 cm2 (~81.8% screen-to-body ratio)                   11
# 1.8 inches, 10.2 cm2                                                  11
# 4.0 inches, 45.5 cm2 (~55.6% screen-to-body ratio)                    11
# 6.52 inches, 102.6 cm2 (~82.3% screen-to-body ratio)                  11
# 5.5 inches, 83.4 cm2 (~71.0% screen-to-body ratio)                    10
# 4.0 inches, 45.5 cm2 (~56.7% screen-to-body ratio)                    10
# 3.5 inches, 36.5 cm2 (~50.7% screen-to-body ratio)                    10
# 1.8 inches, 10.2 cm2 (~20.5% screen-to-body ratio)                    10
# 3.5 inches, 36.5 cm2 (~49.9% screen-to-body ratio)                    10
# 3.5 inches, 36.5 cm2 (~51.6% screen-to-body ratio)                    10
# 5.5 inches, 83.4 cm2 (~71.8% screen-to-body ratio)                    10
# 5.5 inches, 83.4 cm2 (~70.0% screen-to-body ratio)                    10
# 5.0 inches, 68.9 cm2 (~68.2% screen-to-body ratio)                    10
# 4.0 inches, 45.5 cm2 (~59.6% screen-to-body ratio)                    10
# 2.0 inches, 12.4 cm2 (~24.9% screen-to-body ratio)                    10
# 4.0 inches, 45.5 cm2 (~57.6% screen-to-body ratio)                    10
# 4.0 inches, 45.5 cm2 (~58.2% screen-to-body ratio)                    10
# 2.4 inches, 17.8 cm2 (~29.5% screen-to-body ratio)                    10
# 3.5 inches, 36.5 cm2 (~50.9% screen-to-body ratio)                    10
# 5.0 inches, 68.9 cm2 (~64.6% screen-to-body ratio)                    10
# 5.0 inches, 68.9 cm2 (~67.5% screen-to-body ratio)                    10
# 5.5 inches, 83.4 cm2 (~72.3% screen-to-body ratio)                    10
# 4.0 inches, 45.5 cm2 (~58.0% screen-to-body ratio)                     9
# 4.0 inches, 45.5 cm2 (~56.5% screen-to-body ratio)                     9
# 1.8 inches, 10.2 cm2 (~21.6% screen-to-body ratio)                     9
# 5.0 inches, 68.9 cm2 (~65.7% screen-to-body ratio)                     9
# 5.0 inches, 68.9 cm2 (~65.2% screen-to-body ratio)                     9
# 1.8 inches, 10.2 cm2 (~20.3% screen-to-body ratio)                     9
# 6.67 inches, 107.4 cm2 (~86.0% screen-to-body ratio)                   9
# 2.0 inches, 12.6 cm2 (~26.8% screen-to-body ratio)                     9
# 2.0 inches, 12.4 cm2 (~25.6% screen-to-body ratio)                     9
# 5.0 inches, 68.9 cm2 (~64.8% screen-to-body ratio)                     9
# 2.2 inches, 15.0 cm2 (~27.5% screen-to-body ratio)                     9
# 5.5 inches, 83.4 cm2 (~72.5% screen-to-body ratio)                     9
# 2.8 inches, 42 x 57 mm, 24.3 cm2 (~38.8% screen-to-body ratio)         9
# 2.4 inches, 17.8 cm2 (~31.3% screen-to-body ratio)                     9
# 5.2 inches, 74.5 cm2 (~68.6% screen-to-body ratio)                     9
# 4.0 inches, 45.5 cm2 (~57.2% screen-to-body ratio)                     9
# 6.53 inches, 102.9 cm2 (~81.0% screen-to-body ratio)                   9
# 1.8 inches, 10.2 cm2 (~21.0% screen-to-body ratio)                     9
# 5.5 inches, 83.4 cm2 (~70.4% screen-to-body ratio)                     9
# 5.0 inches, 68.9 cm2 (~64.4% screen-to-body ratio)                     9
# 4.7 inches, 60.9 cm2 (~65.4% screen-to-body ratio)                     9
# 6.53 inches, 104.7 cm2 (~84.4% screen-to-body ratio)                   9
# 1.8 inches, 10.2 cm2 (~20.6% screen-to-body ratio)                     9
# 6.56 inches, 103.4 cm2 (~84.2% screen-to-body ratio)                   9
# 10.1 inches, 295.8 cm2 (~62.2% screen-to-body ratio)                   9
# 6.56 inches, 103.4 cm2 (~84.0% screen-to-body ratio)                   9
# 10.1 inches, 295.8 cm2 (~77.4% screen-to-body ratio)                   9
# 6.58 inches, 104.3 cm2 (~83.9% screen-to-body ratio)                   8
# 5.0 inches, 68.9 cm2 (~63.9% screen-to-body ratio)                     8
# 6.64 inches, 106.8 cm2 (~85.4% screen-to-body ratio)                   8
# 3.5 inches, 36.5 cm2 (~52.0% screen-to-body ratio)                     8
# 5.2 inches, 74.5 cm2 (~70.9% screen-to-body ratio)                     8
# 2.4 inches, 17.8 cm2 (~30.1% screen-to-body ratio)                     8
# 3.5 inches, 36.5 cm2 (~52.4% screen-to-body ratio)                     8
# 2.8 inches, 24.3 cm2 (~41.7% screen-to-body ratio)                     8
# 6.51 inches, 102.3 cm2 (~82.5% screen-to-body ratio)                   8
# 6.5 inches, 102.0 cm2 (~82.9% screen-to-body ratio)                    8
# 6.22 inches, 96.6 cm2 (~82.9% screen-to-body ratio)                    8
# 4.8 inches, 63.5 cm2 (~65.9% screen-to-body ratio)                     8
# 6.5 inches, 102.0 cm2 (~83.8% screen-to-body ratio)                    8
# 1.8 inches, 10.2 cm2 (~20.9% screen-to-body ratio)                     8
# 2.4 inches, 17.8 cm2 (~26.4% screen-to-body ratio)                     8
# 4.7 inches, 60.9 cm2 (~66.7% screen-to-body ratio)                     8
# 5.5 inches, 83.4 cm2 (~71.2% screen-to-body ratio)                     8
# 4.5 inches, 55.8 cm2 (~63.6% screen-to-body ratio)                     8
# 2.0 inches, 12.6 cm2 (~24.2% screen-to-body ratio)                     8
# 4.0 inches, 45.5 cm2 (~57.7% screen-to-body ratio)                     8
# 6.67 inches, 107.4 cm2 (~85.9% screen-to-body ratio)                   8
# 4.0 inches, 45.5 cm2 (~57.0% screen-to-body ratio)                     8
# 4.5 inches, 55.8 cm2 (~61.5% screen-to-body ratio)                     8
# 5.5 inches, 83.4 cm2 (~73.8% screen-to-body ratio)                     8
# 4.5 inches, 55.8 cm2 (~64.6% screen-to-body ratio)                     8
# 2.2 inches, 15.0 cm2 (~29.1% screen-to-body ratio)                     8
# 5.5 inches, 83.4 cm2 (~67.7% screen-to-body ratio)                     8
# 6.78 inches, 109.5 cm2 (~82.2% screen-to-body ratio)                   8
# 6.67 inches, 107.4 cm2 (~86.1% screen-to-body ratio)                   8
# 4.0 inches, 45.5 cm2 (~56.0% screen-to-body ratio)                     8
# 5.5 inches, 83.4 cm2 (~70.1% screen-to-body ratio)                     8
# 5.0 inches, 68.9 cm2 (~67.3% screen-to-body ratio)                     8
# 4.5 inches, 55.8 cm2 (~61.3% screen-to-body ratio)                     8
# 2.4 inches, 17.8 cm2 (~31.7% screen-to-body ratio)                     8
# 1.5 inches, 7.3 cm2 (~16.1% screen-to-body ratio)                      8
# 5.5 inches, 83.4 cm2 (~71.9% screen-to-body ratio)                     8
# 6.5 inches, 102.0 cm2 (~83.7% screen-to-body ratio)                    8
# 6.21 inches, 94.7 cm2 (~83.1% screen-to-body ratio)                    8
# 3.5 inches, 36.5 cm2 (~50.3% screen-to-body ratio)                     8
# 4.5 inches, 55.8 cm2 (~63.4% screen-to-body ratio)                     8
# 4.0 inches, 45.5 cm2 (~57.5% screen-to-body ratio)                     8
# 6.52 inches, 102.6 cm2 (~81.4% screen-to-body ratio)                   7
# 1.9 inches                                                             7
# 2.8 inches, 24.3 cm2 (~38.1% screen-to-body ratio)                     7
# 4.5 inches, 55.8 cm2 (~61.2% screen-to-body ratio)                     7
# 5.5 inches, 83.4 cm2 (~70.2% screen-to-body ratio)                     7
# 5.5 inches, 83.4 cm2 (~68.8% screen-to-body ratio)                     7
# 6.67 inches, 107.4 cm2 (~85.0% screen-to-body ratio)                   7
# 4.5 inches, 55.8 cm2 (~63.5% screen-to-body ratio)                     7
# 3.0 inches, 25.6 cm2 (~43.9% screen-to-body ratio)                     7
# 7.0 inches, 139.5 cm2                                                  7
# 6.58 inches, 104.3 cm2 (~84.2% screen-to-body ratio)                   7
# 6.35 inches, 99.6 cm2 (~81.4% screen-to-body ratio)                    7
# 6.51 inches, 102.3 cm2 (~81.8% screen-to-body ratio)                   7
# 6.67 inches, 107.4 cm2 (~84.6% screen-to-body ratio)                   7
# 6.53 inches, 104.7 cm2 (~83.4% screen-to-body ratio)                   7
# 4.7 inches, 60.9 cm2 (~64.6% screen-to-body ratio)                     7
# 1.8 inches, 10.2 cm2 (~19.7% screen-to-body ratio)                     7
# 4.3 inches, 52.6 cm2 (~61.5% screen-to-body ratio)                     7
# 6.38 inches, 99.9 cm2 (~83.3% screen-to-body ratio)                    7
# 4.3 inches, 52.6 cm2 (~59.8% screen-to-body ratio)                     7
# 1.8 inches, 10.2 cm2 (~20.7% screen-to-body ratio)                     7
# 1.8 inches, 10.2 cm2 (~20.2% screen-to-body ratio)                     7
# 4.5 inches, 55.8 cm2 (~61.9% screen-to-body ratio)                     7
# 1.8 inches, 10.2 cm2 (~21.4% screen-to-body ratio)                     7
# 5.5 inches, 83.4 cm2 (~72.1% screen-to-body ratio)                     7
# 5.5 inches, 83.4 cm2 (~73.3% screen-to-body ratio)                     7
# 5.0 inches, 68.9 cm2 (~69.2% screen-to-body ratio)                     7
# 2.2 inches, 15.0 cm2 (~30.3% screen-to-body ratio)                     7
# 1.8 inches, 10.2 cm2 (~21.1% screen-to-body ratio)                     7
# 5.0 inches, 68.9 cm2 (~68.5% screen-to-body ratio)                     7
# 6.67 inches, 107.4 cm2 (~86.7% screen-to-body ratio)                   7
# 2.4 inches, 17.8 cm2 (~34.3% screen-to-body ratio)                     7
# 5.0 inches, 68.9 cm2 (~72.3% screen-to-body ratio)                     7
# 6.67 inches, 107.4 cm2 (~87.5% screen-to-body ratio)                   7
# 6.5 inches, 102.0 cm2 (~82.1% screen-to-body ratio)                    7
# 6.47 inches, 102.8 cm2 (~87.9% screen-to-body ratio)                   7
# 6.5 inches, 102.0 cm2 (~80.8% screen-to-body ratio)                    7
# 6.5 inches, 102.0 cm2 (~83.0% screen-to-body ratio)                    7
# 9.7 inches, 291.4 cm2 (~65.1% screen-to-body ratio)                    7
# 2.44 inches, 18.4 cm2 (~28.2% screen-to-body ratio)                    7
# 2.8 inches, 24.3 cm2 (~39.1% screen-to-body ratio)                     7
# 3.2 inches, 30.5 cm2 (~48.2% screen-to-body ratio)                     7
# 6.52 inches, 102.6 cm2 (~82.1% screen-to-body ratio)                   7
# 5.0 inches, 68.9 cm2 (~67.8% screen-to-body ratio)                     7
# 4.0 inches, 45.5 cm2 (~58.8% screen-to-body ratio)                     7
# 2.0 inches, 12.6 cm2 (~27.0% screen-to-body ratio)                     7
# 6.43 inches, 99.8 cm2 (~84.9% screen-to-body ratio)                    7
# 6.5 inches, 102.0 cm2 (~80.6% screen-to-body ratio)                    7
# 5.5 inches, 83.4 cm2 (~68.1% screen-to-body ratio)                     7
# 5.45 inches, 76.7 cm2 (~72.7% screen-to-body ratio)                    7
# 6.6 inches, 104.6 cm2                                                  7
# 6.09 inches, 91.0 cm2 (~79.2% screen-to-body ratio)                    7
# 6.58 inches, 104.3 cm2 (~83.6% screen-to-body ratio)                   7
# 2.0 inches, 12.6 cm2 (~27.6% screen-to-body ratio)                     6
# 5.5 inches, 83.4 cm2 (~72.4% screen-to-body ratio)                     6
# 4.0 inches, 45.5 cm2 (~55.9% screen-to-body ratio)                     6
# 2.4 inches, 17.8 cm2 (~30.0% screen-to-body ratio)                     6
# 4.0 inches, 45.5 cm2 (~57.9% screen-to-body ratio)                     6
# 1.5 inches, 7.3 cm2 (~14.9% screen-to-body ratio)                      6
# 2.2 inches, 15.0 cm2 (~29.4% screen-to-body ratio)                     6
# 6.43 inches, 99.8 cm2 (~85.9% screen-to-body ratio)                    6
# 2.0 inches, 12.6 cm2 (~27.9% screen-to-body ratio)                     6
# 4.0 inches, 45.5 cm2 (~56.8% screen-to-body ratio)                     6
# 6.6 inches, 104.9 cm2 (~82.5% screen-to-body ratio)                    6
# 5.5 inches, 83.4 cm2 (~72.0% screen-to-body ratio)                     6
# 6.43 inches, 99.8 cm2 (~84.5% screen-to-body ratio)                    6
# 1.5 inches, 7.3 cm2                                                    6
# 5.1 inches, 71.7 cm2 (~69.6% screen-to-body ratio)                     6
# 3.5 inches, 36.5 cm2 (~51.2% screen-to-body ratio)                     6
# 5.7 inches, 83.8 cm2 (~76.0% screen-to-body ratio)                     6
# 4.3 inches, 52.6 cm2 (~61.9% screen-to-body ratio)                     6
# 1.63 inches                                                            6
# 4.0 inches, 45.5 cm2 (~59.3% screen-to-body ratio)                     6
# 2.0 inches, 12.4 cm2 (~24.8% screen-to-body ratio)                     6
# 5.99 inches, 92.6 cm2 (~77.4% screen-to-body ratio)                    6
# 3.5 inches, 36.5 cm2 (~51.5% screen-to-body ratio)                     6
# 1.8 inches, 10.2 cm2 (~18.6% screen-to-body ratio)                     6
# 2.4 inches, 17.8 cm2 (~31.5% screen-to-body ratio)                     6
# 5.2 inches, 74.5 cm2 (~69.2% screen-to-body ratio)                     6
# 2.4 inches, 17.8 cm2 (~29.8% screen-to-body ratio)                     6
# 10.1 inches, 295.8 cm2 (~71.0% screen-to-body ratio)                   6
# 2.0 inches, 12.4 cm2 (~24.7% screen-to-body ratio)                     6
# 1.8 inches, 10.2 cm2 (~22.2% screen-to-body ratio)                     6
# 6.58 inches, 104.3 cm2 (~83.4% screen-to-body ratio)                   6
# 5.0 inches, 68.9 cm2 (~64.1% screen-to-body ratio)                     6
# 5.0 inches, 68.9 cm2 (~69.9% screen-to-body ratio)                     6
# 5.0 inches, 68.9 cm2 (~71.1% screen-to-body ratio)                     6
# 1.32 inches, 5.2 cm2 (~10.4% screen-to-body ratio)                     6
# 2.2 inches, 15.0 cm2 (~29.7% screen-to-body ratio)                     6
# 6.52 inches, 102.6 cm2 (~81.8% screen-to-body ratio)                   6
# 4.3 inches, 51.0 cm2 (~62.2% screen-to-body ratio)                     6
# 6.2 inches, 95.9 cm2 (~81.2% screen-to-body ratio)                     6
# 2.0 inches, 12.6 cm2 (~24.7% screen-to-body ratio)                     6
# 2.4 inches, 17.8 cm2 (~30.4% screen-to-body ratio)                     6
# 2.4 inches, 17.8 cm2 (~31.0% screen-to-body ratio)                     6
# 4.0 inches, 44.1 cm2 (~60.8% screen-to-body ratio)                     6
# 2.4 inches, 17.8 cm2 (~25.9% screen-to-body ratio)                     6
# 2.4 inches, 17.8 cm2 (~34.0% screen-to-body ratio)                     6
# 4.0 inches, 45.5 cm2 (~54.3% screen-to-body ratio)                     6
# 5.2 inches, 74.5 cm2 (~67.7% screen-to-body ratio)                     6
# 4.7 inches, 60.9 cm2 (~65.6% screen-to-body ratio)                     6
# 4.3 inches, 51.0 cm2 (~60.3% screen-to-body ratio)                     6
# 2.2 inches, 15.0 cm2 (~31.9% screen-to-body ratio)                     6
# 6.0 inches, 99.2 cm2 (~71.2% screen-to-body ratio)                     6
# 4.7 inches, 60.9 cm2 (~70.1% screen-to-body ratio)                     6
# 5.0 inches, 68.9 cm2 (~64.0% screen-to-body ratio)                     6
# 6.38 inches, 99.9 cm2 (~83.4% screen-to-body ratio)                    6
# 6.52 inches, 102.6 cm2 (~81.2% screen-to-body ratio)                   6
# 5.0 inches, 68.9 cm2 (~71.7% screen-to-body ratio)                     6
# 5.5 inches, 83.4 cm2 (~72.6% screen-to-body ratio)                     6
# 6.52 inches, 102.6 cm2 (~82.9% screen-to-body ratio)                   6
# 4.0 inches, 45.5 cm2 (~57.1% screen-to-body ratio)                     6
# 6.6 inches, 105.2 cm2 (~83.1% screen-to-body ratio)                    6
# 6.5 inches, 103.7 cm2 (~83.1% screen-to-body ratio)                    6
# 4.0 inches, 45.5 cm2 (~59.9% screen-to-body ratio)                     6
# 5.5 inches, 83.4 cm2 (~68.9% screen-to-body ratio)                     6
# 3.0 inches, 25.6 cm2 (~43.2% screen-to-body ratio)                     6
# 4.5 inches, 55.8 cm2 (~60.1% screen-to-body ratio)                     6
# 2.0 inches                                                             6
# 3.2 inches, 30.5 cm2 (~45.3% screen-to-body ratio)                     6
# 5.0 inches, 68.9 cm2 (~64.9% screen-to-body ratio)                     6
# 2.8 inches, 24.3 cm2 (~42.4% screen-to-body ratio)                     6
# 5.5 inches, 83.4 cm2 (~68.5% screen-to-body ratio)                     6
# 2.4 inches, 17.8 cm2 (~31.2% screen-to-body ratio)                     6
# 2.4 inches, 17.8 cm2 (~36.9% screen-to-body ratio)                     6
# 2.0 inches, 12.6 cm2 (~26.1% screen-to-body ratio)                     6
# 1.5 inches, 7.3 cm2 (~15.3% screen-to-body ratio)                      6
# 1.77 inches, 9.9 cm2 (~20.4% screen-to-body ratio)                     6
# 7.0 inches, 137.9 cm2 (~60.2% screen-to-body ratio)                    6
# 6.78 inches, 111.0 cm2 (~90.4% screen-to-body ratio)                   6
# 5.5 inches, 83.4 cm2 (~73.6% screen-to-body ratio)                     6
# 2.8 inches, 24.3 cm2 (~40.9% screen-to-body ratio)                     6
# 6.39 inches, 100.2 cm2 (~82.4% screen-to-body ratio)                   6
# 4.7 inches, 60.9 cm2                                                   6
# 1.5 inches, 27 x 27 mm, 7.3 cm2 (~16.2% screen-to-body ratio)          5
# 3.5 inches, 36.5 cm2 (~51.1% screen-to-body ratio)                     5
# 2.4 inches, 17.8 cm2 (~31.9% screen-to-body ratio)                     5
# 5.5 inches, 83.4 cm2 (~68.7% screen-to-body ratio)                     5
# 12.2 inches, 431.6 cm2 (~71.6% screen-to-body ratio)                   5
# 6.2 inches, 95.9 cm2 (~80.7% screen-to-body ratio)                     5
# 4.0 inches, 45.5 cm2 (~55.0% screen-to-body ratio)                     5
# 6.0 inches, 99.2 cm2 (~75.9% screen-to-body ratio)                     5
# 3.7 inches, 39.0 cm2                                                   5
# 6.67 inches, 107.4 cm2 (~87.2% screen-to-body ratio)                   5
# 10.1 inches, 295.8 cm2 (~73.6% screen-to-body ratio)                   5
# 6.6 inches, 103.4 cm2 (~85.1% screen-to-body ratio)                    5
# 6.43 inches, 99.8 cm2 (~85.2% screen-to-body ratio)                    5
# 4.0 inches, 45.5 cm2 (~59.0% screen-to-body ratio)                     5
# 6.67 inches, 107.4 cm2 (~84.8% screen-to-body ratio)                   5
# 6.51 inches, 102.3 cm2 (~82.1% screen-to-body ratio)                   5
# 5.5 inches, 83.4 cm2 (~73.1% screen-to-body ratio)                     5
# 6.78 inches, 109.5 cm2 (~82.0% screen-to-body ratio)                   5
# 7.0 inches, 137.9 cm2 (~54.7% screen-to-body ratio)                    5
# 1.5 inches, 7.3 cm2 (~15.6% screen-to-body ratio)                      5
# 2.0 inches, 12.6 cm2 (~31.1% screen-to-body ratio)                     5
# 6.39 inches, 100.2 cm2 (~86.1% screen-to-body ratio)                   5
# 2.0 inches, 12.6 cm2 (~26.4% screen-to-body ratio)                     5
# 6.67 inches, 107.4 cm2 (~84.5% screen-to-body ratio)                   5
# 6.5 inches, 102.0 cm2 (~82.3% screen-to-body ratio)                    5
# 4.5 inches, 55.8 cm2 (~62.9% screen-to-body ratio)                     5
# 2.8 inches, 24.3 cm2 (~35.9% screen-to-body ratio)                     5
# 5.5 inches, 83.4 cm2 (~69.7% screen-to-body ratio)                     5
# 11.0 inches, 344.4 cm2 (~81.8% screen-to-body ratio)                   5
# 5.5 inches, 83.4 cm2 (~67.8% screen-to-body ratio)                     5
# 4.0 inches, 45.5 cm2 (~58.7% screen-to-body ratio)                     5
# 4.0 inches, 45.5 cm2 (~55.7% screen-to-body ratio)                     5
# 6.1 inches, 90.2 cm2 (~86.0% screen-to-body ratio)                     5
# 6.52 inches, 102.6 cm2 (~83.0% screen-to-body ratio)                   5
# 6.43 inches, 99.8 cm2 (~84.4% screen-to-body ratio)                    5
# 3.2 inches, 30.5 cm2 (~46.7% screen-to-body ratio)                     5
# 5.5 inches, 83.4 cm2 (~69.6% screen-to-body ratio)                     5
# 9.7 inches, 291.4 cm2 (~71.6% screen-to-body ratio)                    5
# 6.5 inches, 102.8 cm2 (~82.2% screen-to-body ratio)                    5
# 2.2 inches, 15.0 cm2 (~28.5% screen-to-body ratio)                     5
# 2.0 inches, 12.6 cm2 (~25.7% screen-to-body ratio)                     5
# 4.3 inches, 51.0 cm2 (~61.3% screen-to-body ratio)                     5
# 5.0 inches, 68.9 cm2 (~69.4% screen-to-body ratio)                     5
# 6.52 inches, 102.6 cm2 (~81.6% screen-to-body ratio)                   5
# 2.4 inches, 17.8 cm2 (~27.3% screen-to-body ratio)                     5
# 6.72 inches, 109.0 cm2 (~86.6% screen-to-body ratio)                   5
# 2.4 inches, 17.8 cm2 (~35.7% screen-to-body ratio)                     5
# 2.2 inches, 15.0 cm2 (~33.9% screen-to-body ratio)                     5
# 6.5 inches, 102.0 cm2                                                  5
# 1.77 inches, 9.9 cm2 (~19.3% screen-to-body ratio)                     5
# 6.26 inches, 97.8 cm2 (~84.2% screen-to-body ratio)                    5
# 2.8 inches, 24.3 cm2 (~41.0% screen-to-body ratio)                     5
# 6.6 inches, 104.6 cm2 (~84.6% screen-to-body ratio)                    5
# 2.0 inches, 12.4 cm2 (~16.4% screen-to-body ratio)                     5
# 2.4 inches, 17.8 cm2 (~29.4% screen-to-body ratio)                     5
# 6.7 inches, 108.4 cm2 (~86.0% screen-to-body ratio)                    5
# 4.7 inches, 60.9 cm2 (~65.0% screen-to-body ratio)                     5
# 5.2 inches, 74.5 cm2 (~68.4% screen-to-body ratio)                     5
# 10.1 inches, 295.8 cm2 (~63.2% screen-to-body ratio)                   5
# 6.5 inches, 102.0 cm2 (~81.1% screen-to-body ratio)                    5
# 5.0 inches, 68.9 cm2 (~64.3% screen-to-body ratio)                     5
# 2.5 inches, 19.4 cm2 (~25.7% screen-to-body ratio)                     5
# 6.7 inches, 108.0 cm2 (~90.5% screen-to-body ratio)                    5
# 2.3 inches, 16.4 cm2 (~24.6% screen-to-body ratio)                     5
# 2.8 inches, 24.3 cm2 (~38.5% screen-to-body ratio)                     5
# 2.8 inches, 24.3 cm2 (~34.7% screen-to-body ratio)                     5
# 4.5 inches, 55.8 cm2 (~65.5% screen-to-body ratio)                     5
# 5.5 inches, 83.4 cm2 (~73.0% screen-to-body ratio)                     5
# 2.0 inches, 12.6 cm2 (~20.7% screen-to-body ratio)                     5
# 6.78 inches, 111.4 cm2 (~91.1% screen-to-body ratio)                   5
# 2.8 inches, 24.3 cm2 (~38.6% screen-to-body ratio)                     5
# 6.78 inches, 111.0 cm2 (~87.6% screen-to-body ratio)                   5
# 3.2 inches, 30.5 cm2 (~50.9% screen-to-body ratio)                     5
# 2.0 inches, 12.4 cm2 (~25.4% screen-to-body ratio)                     5
# 2.4 inches, 17.8 cm2 (~33.2% screen-to-body ratio)                     5
# 10.1 inches, 295.8 cm2 (~65.8% screen-to-body ratio)                   5
# 2.2 inches, 15.0 cm2 (~29.5% screen-to-body ratio)                     5
# 6.52 inches, 102.6 cm2 (~82.6% screen-to-body ratio)                   5
# 6.6 inches, 105.2 cm2 (~89.3% screen-to-body ratio)                    5
# 1.8 inches, 10.2 cm2 (~24.9% screen-to-body ratio)                     5
# 2.4 inches, 17.8 cm2 (~27.8% screen-to-body ratio)                     5
# 6.67 inches, 107.4 cm2 (~85.7% screen-to-body ratio)                   5
# 3.2 inches, 28.2 cm2 (~49.2% screen-to-body ratio)                     5
# 1.8 inches, 10.2 cm2 (~25.1% screen-to-body ratio)                     5
# 2.8 inches, 24.3 cm2 (~38.4% screen-to-body ratio)                     5
# 2.4 inches, 17.8 cm2 (~24.8% screen-to-body ratio)                     5
# 2.0 inches, 12.6 cm2 (~25.3% screen-to-body ratio)                     5
# 8.0 inches, 185.6 cm2 (~71.3% screen-to-body ratio)                    5
# 3.2 inches, 30.5 cm2 (~46.5% screen-to-body ratio)                     5
# 5.0 inches, 68.9 cm2 (~72.4% screen-to-body ratio)                     5
# 5.45 inches, 76.7 cm2 (~73.8% screen-to-body ratio)                    5
# 3.5 inches, 36.5 cm2 (~50.6% screen-to-body ratio)                     5
# 6.44 inches, 100.1 cm2 (~84.9% screen-to-body ratio)                   5
# 8.0 inches, 185.6 cm2 (~70.9% screen-to-body ratio)                    5
# 1.32 inches                                                            5
# 2.4 inches, 17.8 cm2 (~35.3% screen-to-body ratio)                     5
# 6.81 inches, 112.3 cm2 (~89.2% screen-to-body ratio)                   5
# 4.5 inches, 55.8 cm2 (~62.5% screen-to-body ratio)                     5
# 1.75 inches                                                            5
# 3.5 inches, 36.5 cm2 (~51.8% screen-to-body ratio)                     5
# 4.7 inches, 60.9 cm2 (~64.4% screen-to-body ratio)                     5
# 2.8 inches, 24.3 cm2 (~40.7% screen-to-body ratio)                     5
# 6.7 inches, 108.7 cm2 (~89.6% screen-to-body ratio)                    5
# 2.8 inches, 24.3 cm2 (~41.5% screen-to-body ratio)                     5
# 5.0 inches, 68.9 cm2 (~69.1% screen-to-body ratio)                     5
# 6.22 inches, 96.6 cm2 (~81.8% screen-to-body ratio)                    5
# 3.5 inches, 36.5 cm2 (~52.6% screen-to-body ratio)                     5
# 1.6 inches, 8.3 cm2 (~17.4% screen-to-body ratio)                      5
# 2.8 inches, 24.3 cm2 (~46.7% screen-to-body ratio)                     5
# 8.0 inches, 185.6 cm2 (~72.2% screen-to-body ratio)                    5
# 2.8 inches, 24.3 cm2 (~40.2% screen-to-body ratio)                     5
# 6.64 inches, 106.8 cm2 (~85.6% screen-to-body ratio)                   5
# 6.78 inches, 111.0 cm2 (~90.8% screen-to-body ratio)                   5
# 3.2 inches, 29.1 cm2 (~46.1% screen-to-body ratio)                     5
# 2.8 inches, 24.3 cm2 (~35.2% screen-to-body ratio)                     5
# 6.3 inches, 95.8 cm2 (~81.3% screen-to-body ratio)                     5
# 6.6 inches, 105.2 cm2 (~84.7% screen-to-body ratio)                    5
# 2.8 inches, 24.3 cm2 (~41.9% screen-to-body ratio)                     5
# 3.2 inches, 30.5 cm2 (~45.5% screen-to-body ratio)                     5
# 1.6 inches                                                             5
# 4.7 inches, 60.9 cm2 (~65.8% screen-to-body ratio)                     5
# 6.5 inches, 102.0 cm2 (~82.7% screen-to-body ratio)                    5
# 6.4 inches, 100.5 cm2 (~84.2% screen-to-body ratio)                    5
# 5.0 inches, 68.9 cm2 (~71.9% screen-to-body ratio)                     5
# 7.0 inches, 137.9 cm2                                                  5
# 5.5 inches, 83.4 cm2 (~67.2% screen-to-body ratio)                     5
# 3.5 inches, 53 x 71 mm, 37.9 cm2 (~41.7% screen-to-body ratio)         5
# 5.7 inches, 89.6 cm2 (~72.7% screen-to-body ratio)                     5
# 4.0 inches, 45.5 cm2 (~57.8% screen-to-body ratio)                     5
# 2.6 inches, 20.9 cm2 (~39.5% screen-to-body ratio)                     5
# 4.0 inches, 45.5 cm2 (~61.7% screen-to-body ratio)                     5
# 2.2 inches, 35 x 44 mm, 15.2 cm2 (~25.4% screen-to-body ratio)         5
# 3.2 inches, 30.5 cm2                                                   5
# 2.2 inches, 15.2 cm2 (~26.6% screen-to-body ratio)                     5
# 1.28 inches                                                            5
# 5.5 inches, 83.4 cm2 (~70.5% screen-to-body ratio)                     5
# 2.7 inches, 22.6 cm2 (~38.2% screen-to-body ratio)                     5
# 5.0 inches, 68.9 cm2 (~69.5% screen-to-body ratio)                     5
# 2.8 inches, 24.3 cm2                                                   5
# 4.5 inches, 55.8 cm2 (~60.7% screen-to-body ratio)                     5
# 4.5 inches, 55.8 cm2 (~62.1% screen-to-body ratio)                     5
# 4.3 inches, 51.0 cm2 (~61.8% screen-to-body ratio)                     5
# 6.5 inches, 102.0 cm2 (~81.9% screen-to-body ratio)                    5
# 4.3 inches, 51.0 cm2 (~60.0% screen-to-body ratio)                     5
# 2.4 inches, 17.8 cm2 (~30.9% screen-to-body ratio)                     5
# 6.59 inches, 106.6 cm2 (~84.3% screen-to-body ratio)                   5
# 6.44 inches, 100.1 cm2 (~84.4% screen-to-body ratio)                   5
# 5.7 inches, 83.8 cm2 (~75.4% screen-to-body ratio)                     5
# 2.8 inches, 24.3 cm2 (~40.4% screen-to-body ratio)                     5
# 5.3 inches, 77.4 cm2 (~69.2% screen-to-body ratio)                     5
# 2.4 inches, 17.8 cm2 (~30.8% screen-to-body ratio)                     5
# 3.5 inches, 36.5 cm2 (~52.3% screen-to-body ratio)                     5
# 6.1 inches, 91.3 cm2 (~80.1% screen-to-body ratio)                     5
# 1.8 inches, 10.2 cm2 (~23.9% screen-to-body ratio)                     5
# 1.8 inches, 10.2 cm2 (~22.0% screen-to-body ratio)                     5
# 1.8 inches, 10.2 cm2 (~25.5% screen-to-body ratio)                     5
# 6.67 inches, 107.4 cm2 (~85.2% screen-to-body ratio)                   5
# 6.52 inches, 102.6 cm2 (~81.9% screen-to-body ratio)                   4
# 6.3 inches, 97.4 cm2 (~81.4% screen-to-body ratio)                     4
# 6.76 inches, 115.7 cm2 (~94.1% screen-to-body ratio)                   4
# 6.1 inches, 91.3 cm2 (~80.3% screen-to-body ratio)                     4
# 2.4 inches, 17.8 cm2 (~30.2% screen-to-body ratio)                     4
# 6.53 inches, 104.7 cm2 (~83.5% screen-to-body ratio)                   4
# 2.4 inches, 17.8 cm2 (~30.7% screen-to-body ratio)                     4
# 3.5 inches, 36.5 cm2 (~52.5% screen-to-body ratio)                     4
# 6.5 inches, 102.0 cm2 (~81.3% screen-to-body ratio)                    4
# 6.52 inches, 102.6 cm2 (~80.9% screen-to-body ratio)                   4
# 5.0 inches, 68.9 cm2 (~70.9% screen-to-body ratio)                     4
# 5.5 inches, 83.4 cm2 (~74.4% screen-to-body ratio)                     4
# 5.5 inches, 83.4 cm2 (~72.9% screen-to-body ratio)                     4
# 6.79 inches, 109.5 cm2 (~85.1% screen-to-body ratio)                   4
# 6.5 inches, 102.0 cm2 (~84.1% screen-to-body ratio)                    4
# 5.7 inches, 89.6 cm2 (~74.4% screen-to-body ratio)                     4
# 6.4 inches, 98.9 cm2 (~82.6% screen-to-body ratio)                     4
# 10.1 inches, 295.8 cm2 (~78.7% screen-to-body ratio)                   4
# 3.7 inches, 39.0 cm2 (~54.7% screen-to-body ratio)                     4
# 6.78 inches, 111.4 cm2 (~89.5% screen-to-body ratio)                   4
# 5.7 inches, 83.8 cm2 (~68.2% screen-to-body ratio)                     4
# 2.4 inches, 17.8 cm2 (~31.1% screen-to-body ratio)                     4
# 6.7 inches, 108.7 cm2 (~89.1% screen-to-body ratio)                    4
# 2.2 inches, 15.0 cm2 (~27.8% screen-to-body ratio)                     4
# 4.3 inches, 52.6 cm2 (~61.4% screen-to-body ratio)                     4
# 7.0 inches, 137.9 cm2 (~61.3% screen-to-body ratio)                    4
# 5.99 inches, 92.6 cm2 (~76.3% screen-to-body ratio)                    4
# 6.6 inches, 105.2 cm2 (~84.8% screen-to-body ratio)                    4
# 6.53 inches, 104.7 cm2 (~83.2% screen-to-body ratio)                   4
# 5.2 inches, 74.5 cm2 (~68.7% screen-to-body ratio)                     4
# 4.5 inches, 55.8 cm2 (~62.3% screen-to-body ratio)                     4
# 10.1 inches, 295.8 cm2 (~66.9% screen-to-body ratio)                   4
# 6.7 inches, 108.4 cm2 (~87.6% screen-to-body ratio)                    4
# 1.8 inches, 10.2 cm2 (~21.3% screen-to-body ratio)                     4
# 1.8 inches, 10.2 cm2 (~20.0% screen-to-body ratio)                     4
# 6.52 inches, 102.6 cm2 (~80.6% screen-to-body ratio)                   4
# 1.77 inches, 9.7 cm2 (~16.9% screen-to-body ratio)                     4
# 6.0 inches, 99.2 cm2 (~70.1% screen-to-body ratio)                     4
# 5.5 inches, 83.4 cm2 (~69.1% screen-to-body ratio)                     4
# 2.8 inches, 42 x 57 mm, 24.3 cm2 (~37.0% screen-to-body ratio)         4
# 6.52 inches, 102.6 cm2 (~82.4% screen-to-body ratio)                   4
# 6.3 inches, 95.8 cm2 (~83.2% screen-to-body ratio)                     4
# 2.4 inches, 17.8 cm2 (~26.8% screen-to-body ratio)                     4
# 6.6 inches, 105.2 cm2 (~83.7% screen-to-body ratio)                    4
# 11.0 inches, 350.9 cm2 (~83.6% screen-to-body ratio)                   4
# 2.2 inches, 15.6 cm2 (~29.1% screen-to-body ratio)                     4
# 6.67 inches, 107.4 cm2 (~86.8% screen-to-body ratio)                   4
# 4.3 inches, 51.0 cm2                                                   4
# 1.9 inches, 30 x 37 mm, 11.4 cm2 (~26.6% screen-to-body ratio)         4
# 2.4 inches, 17.8 cm2 (~25.7% screen-to-body ratio)                     4
# 3.25 inches, 32.7 cm2 (~46.7% screen-to-body ratio)                    4
# 2.46 inches, 18.7 cm2 (~28.7% screen-to-body ratio)                    4
# 2.8 inches, 24.3 cm2 (~35.5% screen-to-body ratio)                     4
# 5.71 inches, 81.4 cm2 (~78.1% screen-to-body ratio)                    4
# 7.0 inches, 137.9 cm2 (~57.8% screen-to-body ratio)                    4
# 6.43 inches, 99.8 cm2 (~83.5% screen-to-body ratio)                    4
# 10.4 inches, 307.9 cm2 (~81.0% screen-to-body ratio)                   4
# 6.6 inches, 105.2 cm2 (~83.8% screen-to-body ratio)                    4
# 6.67 inches, 107.4 cm2 (~84.3% screen-to-body ratio)                   4
# 10.1 inches, 295.8 cm2 (~68.9% screen-to-body ratio)                   4
# 1.64 inches                                                            4
# 2.4 inches, 17.8 cm2 (~33.8% screen-to-body ratio)                     4
# 6.6 inches, 105.2 cm2                                                  4
# 4.5 inches, 55.8 cm2 (~59.9% screen-to-body ratio)                     4
# 3.2 inches, 29.1 cm2 (~49.1% screen-to-body ratio)                     4
# 6.78 inches, 109.2 cm2 (~84.7% screen-to-body ratio)                   4
# 3.0 inches, 25.6 cm2 (~46.0% screen-to-body ratio)                     4
# 6.62 inches, 105.8 cm2 (~85.2% screen-to-body ratio)                   4
# 2.4 inches, 17.8 cm2 (~30.5% screen-to-body ratio)                     4
# 6.6 inches, 104.6 cm2 (~84.3% screen-to-body ratio)                    4
# 2.4 inches, 17.8 cm2 (~24.6% screen-to-body ratio)                     4
# 4.5 inches, 55.8 cm2 (~62.6% screen-to-body ratio)                     4
# 5.7 inches, 89.6 cm2 (~67.4% screen-to-body ratio)                     4
# 4.5 inches, 55.8 cm2 (~64.5% screen-to-body ratio)                     4
# 2.2 inches, 15.0 cm2 (~29.2% screen-to-body ratio)                     4
# 1.77 inches, 9.9 cm2 (~22.1% screen-to-body ratio)                     4
# 2.4 inches, 17.8 cm2 (~26.5% screen-to-body ratio)                     4
# 6.44 inches, 100.0 cm2 (~84.7% screen-to-body ratio)                   4
# 1.8 inches, 10.2 cm2 (~19.9% screen-to-body ratio)                     4
# 2.4 inches, 17.8 cm2 (~26.2% screen-to-body ratio)                     4
# 6.52 inches, 102.6 cm2 (~82.5% screen-to-body ratio)                   4
# 6.38 inches, 98.3 cm2 (~84.1% screen-to-body ratio)                    4
# 6.53 inches, 104.7 cm2 (~84.3% screen-to-body ratio)                   4
# 3.2 inches, 30.5 cm2 (~46.9% screen-to-body ratio)                     4
# 4.8 inches, 63.5 cm2 (~65.7% screen-to-body ratio)                     4
# 6.44 inches, 100.1 cm2 (~83.8% screen-to-body ratio)                   4
# 6.0 inches, 99.2 cm2 (~71.7% screen-to-body ratio)                     4
# 4.5 inches, 55.8 cm2 (~64.2% screen-to-body ratio)                     4
# 1.5 inches, 7.3 cm2 (~15.2% screen-to-body ratio)                      4
# 5.0 inches, 71.2 cm2 (~62.4% screen-to-body ratio)                     4
# 2.6 inches, 20.9 cm2                                                   4
# 5.0 inches, 68.9 cm2 (~62.9% screen-to-body ratio)                     4
# 5.0 inches, 68.9 cm2 (~62.5% screen-to-body ratio)                     4
# 1.77 inches, 9.9 cm2                                                   4
# 2.2 inches, 15.0 cm2 (~27.6% screen-to-body ratio)                     4
# 2.0 inches, 12.4 cm2 (~25.1% screen-to-body ratio)                     4
# 1.5 inches, 7.3 cm2 (~16.0% screen-to-body ratio)                      4
# 1.8 inches, 10.2 cm2 (~22.1% screen-to-body ratio)                     4
# 6.51 inches, 102.3 cm2 (~83.0% screen-to-body ratio)                   4
# 10.1 inches, 295.8 cm2 (~64.7% screen-to-body ratio)                   4
# 3.0 inches, 27.9 cm2 (~47.1% screen-to-body ratio)                     4
# 1.8 inches, 10.2 cm2 (~20.1% screen-to-body ratio)                     4
# 5.2 inches, 74.5 cm2 (~69.0% screen-to-body ratio)                     4
# 2.2 inches, 15.0 cm2 (~30.6% screen-to-body ratio)                     4
# 3.7 inches, 37.7 cm2 (~53.6% screen-to-body ratio)                     4
# 2.4 inches, 17.8 cm2 (~29.1% screen-to-body ratio)                     4
# 6.47 inches, 102.8 cm2 (~87.8% screen-to-body ratio)                   4
# 6.44 inches, 100.0 cm2 (~85.1% screen-to-body ratio)                   4
# 2.6 inches, 20.9 cm2 (~34.3% screen-to-body ratio)                     4
# 6.82 inches, 110.5 cm2 (~82.4% screen-to-body ratio)                   4
# 6.82 inches, 110.5 cm2 (~83.1% screen-to-body ratio)                   4
# 6.53 inches, 108.7 cm2 (~94.1% screen-to-body ratio)                   4
# 2.6 inches, 20.9 cm2 (~33.6% screen-to-body ratio)                     4
# 6.0 inches, 92.9 cm2 (~76.0% screen-to-body ratio)                     4
# 6.74 inches, 109.2 cm2 (~87.9% screen-to-body ratio)                   4
# 4.0 inches, 45.5 cm2 (~56.6% screen-to-body ratio)                     4
# 6.6 inches, 104.9 cm2 (~85.0% screen-to-body ratio)                    4
# 5.0 inches, 68.9 cm2 (~63.3% screen-to-body ratio)                     4
# 6.4 inches, 100.5 cm2 (~84.1% screen-to-body ratio)                    4
# 4.5 inches, 55.8 cm2 (~64.3% screen-to-body ratio)                     4
# 1.8 inches, 28 x 35 mm, 10.2 cm2 (~22.2% screen-to-body ratio)         4
# 6.1 inches, 92.3 cm2 (~80.2% screen-to-body ratio)                     4
# 6.26 inches, 97.8 cm2 (~80.0% screen-to-body ratio)                    4
# 6.74 inches, 109.7 cm2 (~85.5% screen-to-body ratio)                   4
# 2.8 inches, 24.3 cm2 (~37.6% screen-to-body ratio)                     4
# 5.5 inches, 78.1 cm2 (~63.8% screen-to-body ratio)                     4
# 5.0 inches, 68.9 cm2 (~58.2% screen-to-body ratio)                     4
# 6.8 inches, 109.8 cm2 (~84.8% screen-to-body ratio)                    4
# 6.62 inches, 105.8 cm2 (~85.7% screen-to-body ratio)                   4
# 6.58 inches, 104.3 cm2 (~71.4% screen-to-body ratio)                   4
# 6.6 inches, 104.8 cm2 (~84.4% screen-to-body ratio)                    4
# 1.77 inches, 9.9 cm2 (~20.6% screen-to-body ratio)                     4
# 5.45 inches, 76.7 cm2 (~63.2% screen-to-body ratio)                    4
# 5.5 inches, 83.4 cm2 (~71.1% screen-to-body ratio)                     4
# 2.2 inches, 15.2 cm2 (~22.7% screen-to-body ratio)                     4
# 5.5 inches, 83.4 cm2 (~68.0% screen-to-body ratio)                     4
# 4.3 inches, 51.0 cm2 (~56.6% screen-to-body ratio)                     4
# 6.52 inches, 102.6 cm2 (~81.5% screen-to-body ratio)                   4
# 4.5 inches, 55.8 cm2 (~66.2% screen-to-body ratio)                     4
# 6.3 inches, 97.4 cm2 (~83.7% screen-to-body ratio)                     4
# 5.0 inches, 68.9 cm2 (~66.1% screen-to-body ratio)                     4
# 1.7 inches                                                             4
# 4.0 inches, 45.5 cm2 (~55.8% screen-to-body ratio)                     4
# 5.0 inches, 68.9 cm2 (~69.7% screen-to-body ratio)                     4
# 2.0 inches, 12.4 cm2 (~26.3% screen-to-body ratio)                     4
# 4.0 inches, 45.5 cm2 (~58.4% screen-to-body ratio)                     4
# 6.58 inches, 104.3 cm2 (~70.3% screen-to-body ratio)                   4
# 1.8 inches, 10.2 cm2 (~18.7% screen-to-body ratio)                     4
# 4.5 inches, 55.8 cm2 (~61.6% screen-to-body ratio)                     4
# 4.5 inches, 55.8 cm2 (~65.2% screen-to-body ratio)                     4
# 3.5 inches, 36.5 cm2 (~51.7% screen-to-body ratio)                     4
# 1.69 inches                                                            4
# 5.2 inches, 74.5 cm2 (~71.4% screen-to-body ratio)                     4
# 5.2 inches, 74.5 cm2 (~69.4% screen-to-body ratio)                     4
# 6.1 inches, 91.3 cm2 (~68.3% screen-to-body ratio)                     4
# 5.0 inches, 68.9 cm2 (~70.6% screen-to-body ratio)                     4
# 1.7 inches, 9.1 cm2 (~20.2% screen-to-body ratio)                      4
# 2.4 inches, 17.8 cm2 (~32.4% screen-to-body ratio)                     4
# 5.7 inches, 83.8 cm2 (~75.7% screen-to-body ratio)                     4
# 7.0 inches, 137.9 cm2 (~58.2% screen-to-body ratio)                    4
# 2.8 inches, 24.3 cm2 (~37.9% screen-to-body ratio)                     4
# 2.4 inches, 17.8 cm2 (~34.5% screen-to-body ratio)                     4
# 1.45 inches, 6.8 cm2 (~13.7% screen-to-body ratio)                     4
# 2.4 inches, 17.8 cm2 (~35.0% screen-to-body ratio)                     4
# 5.2 inches, 74.5 cm2 (~71.0% screen-to-body ratio)                     4
# 5.0 inches, 68.9 cm2 (~70.3% screen-to-body ratio)                     4
# 10.1 inches, 295.8 cm2 (~74.8% screen-to-body ratio)                   4
# 2.4 inches, 17.8 cm2 (~28.2% screen-to-body ratio)                     4
# 5.2 inches, 74.5 cm2 (~70.0% screen-to-body ratio)                     4
# 2.0 inches, 12.6 cm2 (~24.9% screen-to-body ratio)                     4
# 6.7 inches, 108.0 cm2 (~89.6% screen-to-body ratio)                    4
# 11.0 inches, 366.5 cm2 (~82.9% screen-to-body ratio)                   4
# 12.9 inches, 515.3 cm2 (~85.4% screen-to-body ratio)                   4
# 3.5 inches, 34.9 cm2 (~53.2% screen-to-body ratio)                     4
# 3.5 inches, 36.5 cm2 (~52.1% screen-to-body ratio)                     4
# 1.91 inches                                                            4
# 5.5 inches, 83.4 cm2 (~70.9% screen-to-body ratio)                     4
# 6.2 inches, 95.9 cm2 (~81.6% screen-to-body ratio)                     4
# 5.5 inches, 83.4 cm2 (~72.8% screen-to-body ratio)                     4
# 4.3 inches, 52.6 cm2 (~60.1% screen-to-body ratio)                     4
# 1.5 inches, 7.3 cm2 (~18.9% screen-to-body ratio)                      4
# 1.8 inches, 10.2 cm2 (~22.6% screen-to-body ratio)                     4
# 2.8 inches, 24.3 cm2 (~39.5% screen-to-body ratio)                     4
# 6.8 inches, 111.6 cm2 (~85.1% screen-to-body ratio)                    4
# 6.55 inches, 103.6 cm2 (~89.3% screen-to-body ratio)                   4
# 10.1 inches, 295.8 cm2 (~70.0% screen-to-body ratio)                   4
# 6.22 inches, 96.6 cm2 (~80.7% screen-to-body ratio)                    4
# 1.9 inches, 11.4 cm2 (~26.6% screen-to-body ratio)                     4
# 7.0 inches, 137.9 cm2 (~65.3% screen-to-body ratio)                    4
# 5.2 inches, 74.5 cm2 (~69.9% screen-to-body ratio)                     4
# ...
# 5.0 inches, 71.2 cm2 (~65.6% screen-to-body ratio)                     1
# 3.95 inches, 46.5 cm2 (~56.8% screen-to-body ratio)                    1
# 3.5 inches, 36.5 cm2 (~49.3% screen-to-body ratio)                     1
# 5.0 inches, 71.2 cm2 (~60.9% screen-to-body ratio)                     1
# 3.97 inches, 44.9 cm2                                                  1
# 10.1 inches, 287.1 cm2                                                 1
# 4.3 inches, 52.6 cm2 (~64.8% screen-to-body ratio)                     1
# 3.98 inches, 45.1 cm2 (~55.5% screen-to-body ratio)                    1
# 3.5 inches, 37.9 cm2 (~54.6% screen-to-body ratio)                     1
# 2.4 inches, 17.8 cm2 (~29.0% screen-to-body ratio)                     1
# 7.0 inches, 135.1 cm2 (~69.8% screen-to-body ratio)                    1
# 2.0 inches, 12.6 cm2 (~26.3% screen-to-body ratio)                     1
# 3.5 inches, 37.9 cm2 (~52.7% screen-to-body ratio)                     1
# 3.2 inches, 29.1 cm2 (~44.7% screen-to-body ratio)                     1
# 2.55 inches, 2.55, 20.1 cm2 (~33.4% screen-to-body ratio)              1
# 3.1 inches, 29.8 cm2 (~43.2% screen-to-body ratio)                     1
# 3.5 inches, 37.9 cm2 (~49.8% screen-to-body ratio)                     1
# 7.0 inches, 139.5 cm2 (~59.5% screen-to-body ratio)                    1
# 1.46 inches, 6.9 cm2 (~12.6% screen-to-body ratio)                     1
# 3.75 inches, 41.9 cm2 (~55.0% screen-to-body ratio)                    1
# 3.8 inches, 41.1 cm2 (~57.6% screen-to-body ratio)                     1
# 3.2 inches, 31.7 cm2 (~47.2% screen-to-body ratio)                     1
# 2.8 inches, 24.3 cm2 (~31.9% screen-to-body ratio)                     1
# 2.4 inches, 17.8 cm2 (~35.4% screen-to-body ratio)                     1
# 3.5 inches, 33.8 cm2                                                   1
# 5.1 inches, 74.0 cm2 (~74.1% screen-to-body ratio)                     1
# 4.4 inches, 56.1 cm2 (~69.3% screen-to-body ratio)                     1
# 6.43 inches, 99.8 cm2 (~84.0% screen-to-body ratio)                    1
# 5.45 inches, 76.7 cm2 (~72.9% screen-to-body ratio)                    1
# 4.5 inches, 61.9 cm2 (~67.7% screen-to-body ratio)                     1
# 5.7 inches, 85.7 cm2 (~77.2% screen-to-body ratio)                     1
# 4.0 inches, 45.5 cm2 (~43.4% screen-to-body ratio)                     1
# 3.5 inches, 36.5 cm2 (~32.2% screen-to-body ratio)                     1
# 5.5 inches, 83.4 cm2 (~76.0% screen-to-body ratio)                     1
# 5.2 inches, 74.9 cm2 (~68.8% screen-to-body ratio)                     1
# 5.5 inches, 83.4 cm2 (~54.1% screen-to-body ratio)                     1
# 4.8 inches, 63.5 cm2                                                   1
# 4.5 inches, 55.8 cm2 (~60.2% screen-to-body ratio)                     1
# 8.0 inches, 185.6 cm2                                                  1
# 4.7 inches, 62.9 cm2                                                   1
# 4.7 inches, 60.9 cm2 (~61.8% screen-to-body ratio)                     1
# 5.0 inches, 69.4 cm2                                                   1
# 4.7 inches, 62.9 cm2 (~63.0% screen-to-body ratio)                     1
# 4.0 inches, 45.5 cm2 (~55.5% screen-to-body ratio)                     1
# 2.4 inches, 17.8 cm2 (~27.0% screen-to-body ratio)                     1
# 2.3 inches, 16.4 cm2 (~26.1% screen-to-body ratio)                     1
# 1.76 inches, 9.7 cm2 (~19.6% screen-to-body ratio)                     1
# 4.0 inches, 45.5 cm2 (~50.3% screen-to-body ratio)                     1
# 4.7 inches, 60.9 cm2 (~58.7% screen-to-body ratio)                     1
# 2.2 inches, 15.2 cm2 (~26.8% screen-to-body ratio)                     1
# 2.2 inches, 15.0 cm2 (~28.2% screen-to-body ratio)                     1
# 5.5 inches, 85.2 cm2 (~73.7% screen-to-body ratio)                     1
# 1.3 inches, 5.2 cm2 (~13.3% screen-to-body ratio)                      1
# 3.4 inches, 34.4 cm2 (~45.8% screen-to-body ratio)                     1
# 5.7 inches, 89.6 cm2 (~63.5% screen-to-body ratio)                     1
# 2.6 inches, 20.9 cm2 (~37.2% screen-to-body ratio)                     1
# 2.7 inches, 22.6 cm2 (~35.7% screen-to-body ratio)                     1
# 2.7 inches, 41 x 54 mm, 22.6 cm2 (~32.7% screen-to-body ratio)         1
# 2.2 inches, 33 x 45 mm, 15.0 cm2 (~29.1% screen-to-body ratio)         1
# 2.2 inches, 15.0 cm2 (~42.4% screen-to-body ratio)                     1
# 1.3 inches, 5.2 cm2 (~10.0% screen-to-body ratio)                      1
# 1.3 inches, 5.2 cm2 (~11.6% screen-to-body ratio)                      1
# 1.3 inches, 5.2 cm2 (~12.1% screen-to-body ratio)                      1
# 1.3 inches, 5.2 cm2 (~12.2% screen-to-body ratio)                      1
# 1.3 inches, 5.2 cm2 (~10.2% screen-to-body ratio)                      1
# 3.4 inches, 34.4 cm2 (~51.6% screen-to-body ratio)                     1
# 1.3 inches, 5.2 cm2 (~19.3% screen-to-body ratio)                      1
# 6.6 inches, 103.6 cm2 (~90.8% screen-to-body ratio)                    1
# 6.55 inches, 103.6 cm2 (~90.1% screen-to-body ratio)                   1
# 6.6 inches, 105.2 cm2 (~87.5% screen-to-body ratio)                    1
# 6.5 inches, 102.0 cm2 (~84.5% screen-to-body ratio)                    1
# 6.67 inches, 108.0 cm2 (~90.5% screen-to-body ratio)                   1
# 6.6 inches, 105.2 cm2 (~89.0% screen-to-body ratio)                    1
# 6.7 inches, 108.4 cm2 (~90.9% screen-to-body ratio)                    1
# 6.6 inches, 103.6 cm2 (~86.8% screen-to-body ratio)                    1
# 6.67 inches, 107.4 cm2 (~90.3% screen-to-body ratio)                   1
# 6.28 inches, 95.2 cm2 (~87.5% screen-to-body ratio)                    1
# 2.6 inches, 20.9 cm2 (~36.8% screen-to-body ratio)                     1
# 10.6 inches, 309.7 cm2 (~65.6% screen-to-body ratio)                   1
# 1.77 inches, 9.9 cm2 (~18.9% screen-to-body ratio)                     1
# 1.5 inches, 7.3 cm2 (~15.0% screen-to-body ratio)                      1
# 3.2 inches, 32.2 cm2                                                   1
# 3.2 inches, 31.7 cm2 (~50.1% screen-to-body ratio)                     1
# 2.8 inches, 22.3 cm2 (~36.8% screen-to-body ratio)                     1
# 2.2 inches, 15.2 cm2 (~28.0% screen-to-body ratio)                     1
# 1.44 inches, 6.7 cm2 (~14.0% screen-to-body ratio)                     1
# 1.75 inches, 9.6 cm2                                                   1
# 1.46 inches, 6.9 cm2                                                   1
# 2.8 inches, 22.3 cm2 (~36.7% screen-to-body ratio)                     1
# 2.2 inches, 15.2 cm2 (~28.1% screen-to-body ratio)                     1
# 2.2 inches, 15.0 cm2 (~21.0% screen-to-body ratio)                     1
# 1.75 inches, 9.6 cm2 (~19.6% screen-to-body ratio)                     1
# 1.4 inches, 6.3 cm2 (~15.0% screen-to-body ratio)                      1
# 10.6 inches, 309.8 cm2 (~65.4% screen-to-body ratio)                   1
# 1.81 inches, 10.3 cm2 (~22.9% screen-to-body ratio)                    1
# 2.2 inches, 15.2 cm2 (~29.5% screen-to-body ratio)                     1
# 8.3 inches, 204.0 cm2 (~152.6% screen-to-body ratio)                   1
# 8.1 inches, 195.4 cm2 (~144.2% screen-to-body ratio)                   1
# 5.0 inches, 67.5 cm2 (~67.1% screen-to-body ratio)                     1
# 5.7 inches, 89.6 cm2 (~75.2% screen-to-body ratio)                     1
# 5.7 inches, 88.5 cm2 (~74.3% screen-to-body ratio)                     1
# 5.2 inches, 74.5 cm2 (~70.2% screen-to-body ratio)                     1
# 5.2 inches, 74.8 cm2 (~70.5% screen-to-body ratio)                     1
# 4.7 inches, 59.7 cm2 (~64.7% screen-to-body ratio)                     1
# 4.0 inches, 44.8 cm2 (~58.8% screen-to-body ratio)                     1
# 5.36 inches, 81.8 cm2 (~75.5% screen-to-body ratio)                    1
# 5.5 inches, 82.6 cm2 (~72.9% screen-to-body ratio)                     1
# 3.8 inches, 41.1 cm2 (~53.7% screen-to-body ratio)                     1
# 1.77 inches, 9.7 cm2 (~19.9% screen-to-body ratio)                     1
# 3.5 inches, 34.9 cm2 (~48.1% screen-to-body ratio)                     1
# 3.2 inches, 28.2 cm2 (~58.1% screen-to-body ratio)                     1
# 2.8 inches, 22.3 cm2 (~40.0% screen-to-body ratio)                     1
# 3.0 inches, 25.6 cm2 (~42.0% screen-to-body ratio)                     1
# 3.0 inches, 25.6 cm2 (~52.9% screen-to-body ratio)                     1
# 3.0 inches, 25.6 cm2 (~43.6% screen-to-body ratio)                     1
# 4.01 inches, 37.7 cm2 (~57.8% screen-to-body ratio)                    1
# 2.0 inches, 12.4 cm2 (~24.4% screen-to-body ratio)                     1
# 3.0 inches, 25.6 cm2 (~43.3% screen-to-body ratio)                     1
# 3.0 inches, 25.6 cm2 (~41.9% screen-to-body ratio)                     1
# 3.0 inches, 25.6 cm2 (~44.4% screen-to-body ratio)                     1
# 1.76 inches, 9.7 cm2 (~20.2% screen-to-body ratio)                     1
# 3.0 inches, 25.6 cm2 (~44.8% screen-to-body ratio)                     1
# 3.0 inches, 25.6 cm2 (~42.8% screen-to-body ratio)                     1
# 1.5 inches, 7.3 cm2 (~17.5% screen-to-body ratio)                      1
# 1.5 inches, 7.3 cm2 (~17.6% screen-to-body ratio)                      1
# 2.0 inches, 12.6 cm2 (~29.0% screen-to-body ratio)                     1
# 2.0 inches, 12.4 cm2 (~25.5% screen-to-body ratio)                     1
# 3.0 inches, 23.2 cm2 (~44.6% screen-to-body ratio)                     1
# 1.7 inches, 8.9 cm2 (~17.3% screen-to-body ratio)                      1
# 2.0 inches, 12.4 cm2 (~23.9% screen-to-body ratio)                     1
# 1.7 inches, 9.1 cm2 (~22.0% screen-to-body ratio)                      1
# 1.7 inches, 8.9 cm2 (~18.9% screen-to-body ratio)                      1
# 1.0 inches, 3.1 cm2 (~7.6% screen-to-body ratio)                       1
# 4.8 inches, 57.1 cm2 (~60.6% screen-to-body ratio)                     1
# 3.0 inches, 26.8 cm2 (~45.5% screen-to-body ratio)                     1
# 1.76 inches, 9.7 cm2 (~22.6% screen-to-body ratio)                     1
# 3.8 inches, 41.1 cm2 (~63.1% screen-to-body ratio)                     1
# 2.8 inches, 24.3 cm2 (~34.0% screen-to-body ratio)                     1
# 2.2 inches, 15.2 cm2 (~24.6% screen-to-body ratio)                     1
# 2.2 inches, 15.2 cm2 (~31.8% screen-to-body ratio)                     1
# 2.3 inches, 16.4 cm2 (~23.8% screen-to-body ratio)                     1
# 2.3 inches, 16.4 cm2 (~23.3% screen-to-body ratio)                     1
# 2.3 inches, 16.4 cm2 (~23.4% screen-to-body ratio)                     1
# 4.3 inches, 52.6 cm2 (~59.2% screen-to-body ratio)                     1
# 2.0 inches, 12.4 cm2 (~21.3% screen-to-body ratio)                     1
# 2.8 inches, 22.3 cm2 (~28.7% screen-to-body ratio)                     1
# 2.8 inches, 23.3 cm2 (~36.3% screen-to-body ratio)                     1
# 1.7 inches, 9.1 cm2 (~17.7% screen-to-body ratio)                      1
# 3.2 inches, 29.1 cm2 (~44.6% screen-to-body ratio)                     1
# 2.0 inches, 12.6 cm2 (~24.5% screen-to-body ratio)                     1
# 2.8 inches, 22.3 cm2 (~40.9% screen-to-body ratio)                     1
# 3.5 inches, 34.9 cm2 (~52.7% screen-to-body ratio)                     1
# 3.0 inches, 25.6 cm2 (~46.3% screen-to-body ratio)                     1
# 2.2 inches, 15.2 cm2 (~22.5% screen-to-body ratio)                     1
# 2.2 inches, 15.2 cm2 (~25.7% screen-to-body ratio)                     1
# 3.0 inches, 25.6 cm2 (~44.7% screen-to-body ratio)                     1
# 3.2 inches, 29.1 cm2 (~45.3% screen-to-body ratio)                     1
# 3.5 inches, 37.9 cm2 (~56.5% screen-to-body ratio)                     1
# 3.5 inches, 34.9 cm2 (~51.5% screen-to-body ratio)                     1
# 2.8 inches, 22.3 cm2 (~39.6% screen-to-body ratio)                     1
# 3.0 inches, 25.6 cm2 (~42.9% screen-to-body ratio)                     1
# 1.9 inches, 11.4 cm2 (~26.3% screen-to-body ratio)                     1
# 1.77 inches, 9.9 cm2 (~23.3% screen-to-body ratio)                     1
# 5.0 inches, 70.7 cm2 (~69.9% screen-to-body ratio)                     1
# 6.0 inches, 92.9 cm2 (~84.3% screen-to-body ratio)                     1
# 6.5 inches, 106.3 cm2 (~85.2% screen-to-body ratio)                    1
# 6.2 inches, 95.8 cm2 (~85.9% screen-to-body ratio)                     1
# 6.2 inches, 95.8 cm2 (~84.7% screen-to-body ratio)                     1
# 6.2 inches, 97.2 cm2 (~87.2% screen-to-body ratio)                     1
# 6.2 inches, 96.4 cm2 (~84.7% screen-to-body ratio)                     1
# 5.99 inches, 88.1 cm2                                                  1
# 6.0 inches, 92.9 cm2 (~80.1% screen-to-body ratio)                     1
# 6.2 inches, 97.6 cm2 (~86.5% screen-to-body ratio)                     1
# 5.7 inches, 83.8 cm2 (~78.2% screen-to-body ratio)                     1
# 5.7 inches, 83.8 cm2 (~77.6% screen-to-body ratio)                     1
# 6.0 inches, 92.9 cm2 (~83.7% screen-to-body ratio)                     1
# 6.5 inches, 107.9 cm2 (~86.0% screen-to-body ratio)                    1
# 6.79 inches, 107.7 cm2 (~89.9% screen-to-body ratio)                   1
# 5.45 inches, 76.7 cm2 (~74.8% screen-to-body ratio)                    1
# 5.95 inches, 97.6 cm2 (~81.0% screen-to-body ratio)                    1
# 5.46 inches, 82.2 cm2 (~79.8% screen-to-body ratio)                    1
# 5.46 inches, 82.2 cm2 (~79.0% screen-to-body ratio)                    1
# 5.99 inches, 92.6 cm2 (~78.7% screen-to-body ratio)                    1
# 5.7 inches, 88.5 cm2 (~72.9% screen-to-body ratio)                     1
# 5.2 inches, 74.9 cm2 (~71.8% screen-to-body ratio)                     1
# 6.0 inches, 99.2 cm2 (~74.4% screen-to-body ratio)                     1
# 5.2 inches, 74.9 cm2 (~71.6% screen-to-body ratio)                     1
# 5.5 inches, 82.6 cm2 (~71.2% screen-to-body ratio)                     1
# 5.0 inches, 68.9 cm2 (~71.4% screen-to-body ratio)                     1
# 6.81 inches, 112.0 cm2 (~89.3% screen-to-body ratio)                   1
# 4.7 inches, 60.9 cm2 (~63.7% screen-to-body ratio)                     1
# 1.86 inches, 10.9 cm2 (~24.9% screen-to-body ratio)                    1
# 1.3 inches, 5.5 cm2 (~14.2% screen-to-body ratio)                      1
# 1.56 inches, 7.9 cm2 (~18.7% screen-to-body ratio)                     1
# 1.7 inches, 9.1 cm2 (~17.6% screen-to-body ratio)                      1
# 2.0 inches, 30 x 40 mm, 12.4 cm2 (~28.3% screen-to-body ratio)         1
# 2.0 inches, 12.6 cm2 (~25.5% screen-to-body ratio)                     1
# 1.5 inches, 7.0 cm2 (~16.2% screen-to-body ratio)                      1
# 2.2 inches, 15.0 cm2 (~31.2% screen-to-body ratio)                     1
# 1.8 inches, 28 x 37 mm, 10.2 cm2 (~26.0% screen-to-body ratio)         1
# 2.0 inches, 31 x 39 mm, 12.6 cm2 (~27.6% screen-to-body ratio)         1
# 2.0 inches, 31 x 39 mm, 12.6 cm2 (~29.1% screen-to-body ratio)         1
# 2.0 inches, 31 x 39 mm, 12.6 cm2 (~27.7% screen-to-body ratio)         1
# 2.2 inches, 33 x 45 mm, 15.0 cm2 (~29.4% screen-to-body ratio)         1
# 2.2 inches, 35 x 44 mm, 15.2 cm2 (~31.5% screen-to-body ratio)         1
# 5.0 inches, 68.9 cm2 (~58.1% screen-to-body ratio)                     1
# 2.2 inches, 15.6 cm2 (~31.5% screen-to-body ratio)                     1
# 1.3 inches, 5.3 cm2 (~14.8% screen-to-body ratio)                      1
# 2.0 inches, 31 x 39 mm, 12.6 cm2 (~26.0% screen-to-body ratio)         1
# 1.6 inches, 8.3 cm2 (~19.9% screen-to-body ratio)                      1
# 2.2 inches, 35 x 44 mm, 15.2 cm2 (~32.2% screen-to-body ratio)         1
# 2.0 inches, 31 x 39 mm, 12.6 cm2 (~27.9% screen-to-body ratio)         1
# 1.5 inches, 7.3 cm2 (~16.4% screen-to-body ratio)                      1
# 1.6 inches, 8.3 cm2 (~18.6% screen-to-body ratio)                      1
# 3.5 inches, 36.5 cm2 (~49.6% screen-to-body ratio)                     1
# 7.0 inches, 137.9 cm2 (~70.4% screen-to-body ratio)                    1
# 7.0 inches, 137.9 cm2 (~68.9% screen-to-body ratio)                    1
# 3.2 inches, 31.7 cm2 (~49.7% screen-to-body ratio)                     1
# Name: DISPLAY_Size, dtype: int64

# %%
def unifySize(data: pd.DataFrame):
    # Tach chuoi tai tu inch va lay phan truoc
    data['DISPLAY_Size'] = data['DISPLAY_Size'].str.split(' inch').str[0]

    # Chuyen ve dang float
    try:
        # Chuyen ve dang float cho tung dong

# %%
unifySize(dataTemp)
dataTemp['DISPLAY_Size'].value_counts()
# Out:
# 5.0             1052
# 5.5              609
# 4.0              492
# 2.4              467
# 2.0              436
# 1.8              414
# 2.2              370
# 4.5              359
# 2.8              342
# 3.5              329
# 6.5              283
# 7.0              242
# 3.2              228
# 6.0              207
# 10.1             195
# 4.3              185
# 6.67             183
# 5.7              176
# 5.2              169
# 4.7              159
# 6.6              156
# 1.5              155
# 6.7              144
# 3.0              141
# 6.52             135
# 8.0              132
# 2.6              123
# 1.9              119
# 6.4              108
# 1.77             100
# 6.78              96
# 6.2               91
# 6.3               90
# 6.58              89
# 6.1               83
# 6.53              82
# 6.8               82
# 6.43              73
# 3.7               72
# 5.45              68
# 2.1               63
# 6.56              62
# 6.44              57
# 6.51              54
# 6.55              53
# 6.39              49
# 1.6               44
# 5.3               43
# 1.7               42
# 1.3               40
# 2.3               40
# 5.99              39
# 6.82              38
# 6.22              38
# 6.26              37
# 3.8               37
# 4.8               35
# 9.7               34
# 2.5               31
# 11.0              31
# 1.4               31
# 6.57              30
# 3.1               27
# 6.74              27
# 1.52              26
# 1.43              24
# 7.9               24
# 5.1               22
# 6.62              22
# 5.9               22
# 6.59              21
# 6.81              21
# 6.72              20
# 1.78              19
# 6.38              18
# 6.09              18
# 1.39              18
# 4.65              17
# 2.7               17
# 1.45              16
# 6.95              16
# , -               16
# 6.47              16
# 6.21              16
# 6.01              15
# 10.4              15
# 6.64              15
# 3.6               15
# 6.9               14
# 5.71              14
# 1.2               14
# 5.8               14
# 1.32              13
# 10.5              13
# 1.63              12
# 8.9               12
# 6.35              12
# 8.4               11
# 1.65              11
# 2.46              11
# 6.75              11
# 3.3               10
# 2.44              10
# 2.9               10
# 6.28              10
# 1.75              10
# 10.36             10
# 2.36              10
# 3.14               9
# 2.55               9
# 11.5               9
# 4.1                9
# 10.0               9
# 6.41               9
# 6.92               8
# 6.65               8
# 6.73               8
# 5.65               8
# 1.46               8
# 4.2                8
# 1.44               7
# 6.76               7
# 5.15               7
# 7.85               7
# 4.6                7
# 5.84               7
# 10.8               7
# 5.93               7
# 12.2               7
# 12.4               7
# 6.49               7
# 1.55               6
# 5.34               6
# 1.56               6
# 3.25               6
# 5.6                6
# 6.36               6
# 3.4                6
# 1.76               6
# 4.55               6
# 6.18               6
# 12.9               6
# 5.46               5
# 6.79               5
# 4.52               5
# 1.47               5
# 1.93               5
# 12.1               5
# 7.6                5
# 9.6                5
# 8.3                5
# 5.4                5
# 9.4                5
# 10.95              5
# 1.28               5
# 1.91               4
# 1.67               4
# 3.97               4
# 10.2               4
# 10.6               4
# 7.7                4
# 1.85               4
# 1.36               4
# 10.9               4
# 6.19               4
# 1.69               4
# 7.2                4
# 6.85               4
# 6.71               4
# 4.95               4
# 1.64               4
# 1.22               4
# 8.03               4
# 1.66               3
# 4.63               3
# 4.01               3
# 1.38               3
# 7.12               3
# 7.1                3
# 5.98               3
# 2.25               3
# 3.9                3
# 1.37               3
# 3.95               3
# 1.92               3
# 2.63               3
# 7.92               3
# 6.89               3
# 8.2                3
# 6.63               3
# 6.42               3
# 1.1                3
# 3.65               3
# 5.88               3
# 8.7                3
# 6.15               3
# 9.0                3
# 17.3               3
# 5.25               2
# 4.4                2
# 3.75               2
# 2.62               2
# 3.27               2
# 4.66               2
# 2.12               2
# 2.83               2
# 5.43               2
# 1.25               2
# 7.3                2
# 4.13               2
# 5.86               2
# 5.94               2
# 14.6               2
# 7.82               2
# 11.61              2
# 5.67               2
# 1.86               2
# 5.85               2
# 5.72               2
# 2.66               2
# 13.0               2
# 1.0                2
# 10.61              2
# 7.8                2
# 5.96               2
# 12.6               2
# 1.41               2
# 8.1                2
# 2.31               2
# 4.02               2
# 6.66               2
# 1.72               2
# 8.8                2
# 11.2               2
# 2.45               2
# 3.58               2
# 13.3               2
# 7.09               2
# 5.73               2
# 10.3               2
# 3.35               1
# 12.3               1
# 2.26               1
# 5.97               1
# 2.15               1
# 1.96               1
# 8.01               1
# 2.64               1
# 7.86               1
# 8.02               1
# 5.09               1
# 5.81               1
# 1.83               1
# 6.45               1
# 3.55               1
# 1.74               1
# 3.46               1
# 3.44               1
# 2.76               1
# 4.03               1
# 6.34               1
# 2.81               1
# 3.15               1
# 6.24               1
# 12.0               1
# , 53 x 40 mm       1
# 8.88               1
# 0.95               1
# 6.46               1
# 14.0               1
# 18.4               1
# 6.08               1
# 5.92               1
# 2.28               1
# 12.7               1
# 14.5               1
# 1.87               1
# 2.13               1
# 11.6               1
# 6.98               1
# 6.33               1
# 1.81               1
# 10.35              1
# 7.71               1
# 4.93               1
# 3.98               1
# 5.36               1
# 11.35              1
# 2.37               1
# 4.77               1
# 1.54               1
# 4.68               1
# 5.01               1
# 13.2               1
# 6.69               1
# 5.95               1
# 5.83               1
# , 26 x 28 mm       1
# 4.46               1
# 1.31               1
# 2.75               1
# 1.04               1
# 2.41               1
# 8.68               1
# 6.23               1
# 4.99               1
# Name: DISPLAY_Size, dtype: int64

# %%
type(dataTemp['DISPLAY_Size'].iloc[0])
# Out:
# str
