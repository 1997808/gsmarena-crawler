# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
import os

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Branch data

# %% [markdown]
# ## Load data

# %%
Brands_data = pd.read_csv("rawdata/Brands_data.csv")

# %%
Brands_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BrandName      122 non-null    object
#  1   NumberOfPhone  122 non-null    int64
#  2   BrandUrl       122 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 3.0+ KB

# %% [markdown]
# ## Inspection

# %%
def inspect_data(data):
    dataCols = data.columns
    NullSum = data.isnull().sum()
    UniqueSum = data.nunique()
    ColType = data.dtypes
    # nsamples = 5
    # Samples = [', '.join([str(data[col][i]) for i in range(nsamples)]) for col in data.columns]
    n_UniqueSample = 5
    UniqueSamples = [', '.join([str(data[col].unique()[i]) for i in range(n_UniqueSample if len(
        data[col].unique()) > n_UniqueSample else len(data[col].unique()))]) for col in data.columns]

    Inspec = pd.DataFrame({'Column': dataCols, 'NullSum': NullSum,
                          'UniqueSum': UniqueSum, 'Type': ColType, 'Unique Sample': UniqueSamples})
    Inspec.index = [i for i in range(1, len(data.columns)+1)]
    return Inspec

# %%
display(inspect_data(Brands_data))
# Out:
#           Column  NullSum  UniqueSum    Type  \
# 1      BrandName        0        122  object
# 2  NumberOfPhone        0         85   int64
# 3       BrandUrl        0        122  object
#
#                                                                                                                                                                                                                             Unique Sample
# 1                                                                                                                                                                                                    Acer, alcatel, Allview, Amazon, Amoi
# 2                                                                                                                                                                                                                   100, 409, 157, 25, 47
# 3  https://www.gsmarena.com/acer-phones-59.php, https://www.gsmarena.com/alcatel-phones-5.php, https://www.gsmarena.com/allview-phones-88.php, https://www.gsmarena.com/amazon-phones-76.php, https://www.gsmarena.com/amoi-phones-28.php

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, len(Brands_data)/4))
ax = sns.barplot(x="NumberOfPhone", y="BrandName", data=Brands_data)
plt.title('Number of phone in each brand', fontsize=20)
plt.xlabel('Number of devices', fontsize=20)
plt.ylabel('Brand Name', fontsize=20)
# add numbers on each bars
for i, v in enumerate(Brands_data['NumberOfPhone']):
    ax.text(v + 3, i + .25, str(v))
plt.show()

# %%
print('Total number of devieces: ', Brands_data['NumberOfPhone'].sum())
# Out:
# Total number of devieces:  12605

# %% [markdown]
# # Devices url data

# %% [markdown]
# ## Load data

# %%
Devices_url = pd.read_csv("rawdata/Devices_url.csv")

# %%
Devices_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12515 entries, 0 to 12514
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  12515 non-null  object
#  1   DeviceUrl  12515 non-null  object
# dtypes: object(2)
# memory usage: 195.7+ KB

# %% [markdown]
# ## Inspection

# %%
inspect_data(Devices_url)
# Out:
#       Column  NullSum  UniqueSum    Type  \
# 1  BrandName        0        121  object
# 2  DeviceUrl        0      12515  object
#
#                                                                                                                                                                                                                                                                           Unique Sample
# 1                                                                                                                                                                                                                                                  Acer, alcatel, Allview, Amazon, Amoi
# 2  https://www.gsmarena.com/acer_chromebook_tab_10-9139.php, https://www.gsmarena.com/acer_iconia_talk_s-8306.php, https://www.gsmarena.com/acer_liquid_z6_plus-8305.php, https://www.gsmarena.com/acer_liquid_z6-8304.php, https://www.gsmarena.com/acer_iconia_tab_10_a3_a40-8080.php

# %%
# count number of links in each brand
def compareNumberOfLinkWithNumberOfPhone(BrandsData, DevicesUrl):
    com = {
        'BrandName': [],
        'NumberOfPhone': [],
        'NumberOfLink': [],
        'Match': [],
        'MissMatchCount': []
    }
    for i in range(len(BrandsData)):
        com['BrandName'].append(BrandsData['BrandName'][i])

        # get number of phone in each brand
        NumOfPhone = BrandsData['NumberOfPhone'][i]
        com['NumberOfPhone'].append(NumOfPhone)

        # count number of brandname appear in Devices_url
        try:
            NumOfLink = Devices_url['BrandName'].value_counts()[
                BrandsData['BrandName'][i]]
        except:
            NumOfLink = 0
        com['NumberOfLink'].append(NumOfLink)

        # compare number of phone and number of link, if match then True, else False
        com['Match'].append(NumOfLink == NumOfPhone)

        # count number of miss match
        com['MissMatchCount'].append(NumOfPhone - NumOfLink)

    return pd.DataFrame(com)


com = compareNumberOfLinkWithNumberOfPhone(Brands_data, Devices_url)
# get Brands that have number of phone not match with number of link
BrandsNotMatch = com[com['Match'] == False]
display(BrandsNotMatch)
# Out:
#      BrandName  NumberOfPhone  NumberOfLink  Match  MissMatchCount
# 1      alcatel            409           400  False               9
# 14   Blackview             84            80  False               4
# 40      Huawei            436           434  False               2
# 44     Infinix            118           117  False               1
# 52        Lava            141           140  False               1
# 54      Lenovo            245           240  False               5
# 55          LG            667           660  False               7
# 64    Motorola            603           600  False               3
# 74        Oppo            285           280  False               5
# 76     Oukitel             30             0  False              30
# 88      Realme            178           177  False               1
# 90     Samsung           1376          1360  False              16
# 101      Tecno            127           125  False               2
# 117       XOLO             81            80  False               1
# 121        ZTE            363           360  False               3

# %% [markdown]
# # Devices Specs data

# %% [markdown]
# ## Load data

# %%
Specs_data = pd.read_csv("rawdata/Devices_Specs.csv")
Specs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12513 entries, 0 to 12512
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Brand                  12513 non-null  object
#  1   url                    12513 non-null  object
#  2   imgUrl                 12513 non-null  object
#  3   Name                   12513 non-null  object
#  4   NETWORK_Technology     12513 non-null  object
#  5   NETWORK_2G_bands       12513 non-null  object
#  6   NETWORK_3G_bands       8678 non-null   object
#  7   NETWORK_4G_bands       5285 non-null   object
#  8   NETWORK_5G_bands       1087 non-null   object
#  9   NETWORK_GPRS           4178 non-null   object
#  10  NETWORK_EDGE           4185 non-null   object
#  11  NETWORK_Speed          8643 non-null   object
#  12  LAUNCH_Announced       12501 non-null  object
#  13  LAUNCH_Status          12513 non-null  object
#  14  BODY_Dimensions        12492 non-null  object
#  15  BODY_Weight            12422 non-null  object
#  16  BODY_Build             2384 non-null   object
#  17  BODY_SIM               12512 non-null  object
#  18  DISPLAY_Type           12509 non-null  object
#  19  DISPLAY_Size           11306 non-null  object
#  20  DISPLAY_Resolution     12466 non-null  object
#  21  DISPLAY_Protection     2689 non-null   object
#  22  PLATFORM_OS            8741 non-null   object
#  23  PLATFORM_Chipset       7321 non-null   object
#  24  PLATFORM_CPU           8570 non-null   object
#  25  PLATFORM_GPU           7192 non-null   object
#  26  MEMORY_Card_slot       12513 non-null  object
#  27  MEMORY_Internal        10721 non-null  object
#  28  MAIN_CAM_1_Module      12513 non-null  int64
#  29  MAIN_CAM_1_Features    7698 non-null   object
#  30  MAIN_CAM_1_Video       11067 non-null  object
#  31  SELFIE_CAM_2_Module    12513 non-null  int64
#  32  SELFIE_CAM_2_Features  2340 non-null   object
#  33  SELFIE_CAM_2_Video     3789 non-null   object
#  34  SOUND_Loudspeaker      12513 non-null  object
#  35  SOUND_35mm_jack        12445 non-null  object
#  36  COMMS_WLAN             12505 non-null  object
#  37  COMMS_Bluetooth        12511 non-null  object
#  38  COMMS_GPS              12473 non-null  object
#  39  COMMS_NFC              7706 non-null   object
#  40  COMMS_Radio            12444 non-null  object
#  41  COMMS_USB              11609 non-null  object
#  42  FEATURES_Sensors       8393 non-null   object
#  43  BATTERY_Type           12504 non-null  object
#  44  BATTERY_Stand_by       6785 non-null   object
#  45  BATTERY_Talk_time      7141 non-null   object
#  46  BATTERY_Music_play     734 non-null    object
#  47  MISC_Colors            11905 non-null  object
#  48  MISC_SAR               2566 non-null   object
#  49  MISC_SAR_EU            2807 non-null   object
#  50  MISC_Models            3837 non-null   object
#  51  MISC_Price             8439 non-null   object
# dtypes: int64(2), object(50)
# memory usage: 5.0+ MB

# %% [markdown]
# ## Inspection

# %%
inspect_data(Specs_data)
# Out:
#                    Column  NullSum  UniqueSum    Type  \
# 1                   Brand        0        121  object
# 2                     url        0      12513  object
# 3                  imgUrl        0      11973  object
# 4                    Name        0      12513  object
# 5      NETWORK_Technology        0         45  object
# 6        NETWORK_2G_bands        0        223  object
# 7        NETWORK_3G_bands     3835        743  object
# 8        NETWORK_4G_bands     7228       1550  object
# 9        NETWORK_5G_bands    11426        405  object
# 10           NETWORK_GPRS     8335         32  object
# 11           NETWORK_EDGE     8328         29  object
# 12          NETWORK_Speed     3870        370  object
# 13       LAUNCH_Announced       12       2297  object
# 14          LAUNCH_Status        0       1147  object
# 15        BODY_Dimensions       21       9169  object
# 16            BODY_Weight       91       1605  object
# 17             BODY_Build    10129        311  object
# 18               BODY_SIM        1        134  object
# 19           DISPLAY_Type        4        793  object
# 20           DISPLAY_Size     1207       5273  object
# 21     DISPLAY_Resolution       47       1409  object
# 22     DISPLAY_Protection     9824         98  object
# 23            PLATFORM_OS     3772       1629  object
# 24       PLATFORM_Chipset     5192        986  object
# 25           PLATFORM_CPU     3943        881  object
# 26           PLATFORM_GPU     5321        325  object
# 27       MEMORY_Card_slot        0        158  object
# 28        MEMORY_Internal     1792       1136  object
# 29      MAIN_CAM_1_Module        0          2   int64
# 30    MAIN_CAM_1_Features     4815        179  object
# 31       MAIN_CAM_1_Video     1446        561  object
# 32    SELFIE_CAM_2_Module        0          2   int64
# 33  SELFIE_CAM_2_Features    10173         44  object
# 34     SELFIE_CAM_2_Video     8724         89  object
# 35      SOUND_Loudspeaker        0         35  object
# 36        SOUND_35mm_jack       68          8  object
# 37             COMMS_WLAN        8        235  object
# 38        COMMS_Bluetooth        2        179  object
# 39              COMMS_GPS       40        198  object
# 40              COMMS_NFC     4807        114  object
# 41            COMMS_Radio       69        109  object
# 42              COMMS_USB      904        161  object
# 43       FEATURES_Sensors     4120        306  object
# 44           BATTERY_Type        9       1539  object
# 45       BATTERY_Stand_by     5728       1436  object
# 46      BATTERY_Talk_time     5372       1248  object
# 47     BATTERY_Music_play    11779        160  object
# 48            MISC_Colors      608       4879  object
# 49               MISC_SAR     9947       2121  object
# 50            MISC_SAR_EU     9706       1239  object
# 51            MISC_Models     8676       3779  object
# 52             MISC_Price     4074        899  object
#
#                                                                                                                                                                                                                                                                                                                                                                                                                   Unique Sample
# 1                                                                                                                                                                                                                                                                                                                                                                                          Acer, alcatel, Allview, Amazon, Amoi
# 2                                                                                                                                          https://www.gsmarena.com/acer_chromebook_tab_10-9139.php, https://www.gsmarena.com/acer_iconia_talk_s-8306.php, https://www.gsmarena.com/acer_liquid_z6_plus-8305.php, https://www.gsmarena.com/acer_liquid_z6-8304.php, https://www.gsmarena.com/acer_iconia_tab_10_a3_a40-8080.php
# 3                                                                                                            https://fdn2.gsmarena.com/vv/bigpic/acer-chromebook-tab-10.jpg, https://fdn2.gsmarena.com/vv/bigpic/acer-iconia-talk-s.jpg, https://fdn2.gsmarena.com/vv/bigpic/acer-liquid-z6-plus.jpg, https://fdn2.gsmarena.com/vv/bigpic/acer-liquid-z6.jpg, https://fdn2.gsmarena.com/vv/bigpic/acer-iconia-tab-10-a3-a40.jpg
# 4                                                                                                                                                                                                                                                                                                                    Acer Chromebook Tab 10, Acer Iconia Talk S, Acer Liquid Z6 Plus, Acer Liquid Z6, Acer Iconia Tab 10 A3-A40
# 5                                                                                                                                                                                                                                                                                                                                                       No cellular connectivity, GSM / HSPA / LTE, GSM / HSPA, GSM, GSM / UMTS
# 6                                                                                                                                                                                                                        N/A, GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2, GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (dual-SIM model only), GSM 850 / 900 / 1800 / 1900 , GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 & SIM 3
# 7                                                                                                                                                                                                                                                                                                                            nan, HSDPA 850 / 1900 / 2100 ,  HSDPA, HSDPA 900 / 1900 / 2100 - Europe, Taiwan, HSDPA 900 / 2100
# 8                                                                                                                                                                                                                                                                                                                                  nan, 1, 3, 7, 8, 20,  LTE (unspecified),  LTE 800 / 1800 / 2100 / 2600 - Europe, 1, 3, 7, 20
# 9   nan, 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 53, 66, 70, 77, 78, 79 SA/NSA/Sub6 - A3106, 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 53, 66, 70, 77, 78, 79 SA/NSA/Sub6 - A3102, 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 53, 66, 70, 77, 78, 79 SA/NSA/Sub6 - A3094, 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 53, 66, 70, 77, 78, 79 SA/NSA/Sub6 - A3090
# 10                                                                                                                                                                                                                                                                                                                                                                                             No, nan, Yes, Class 10, Class 12
# 11                                                                                                                                                                                                                                                                                                                                                                                             No, nan, Yes, Class 10, Class 12
# 12                                                                                                                                                                                                                                                                                             nan, HSPA 42.2/11.5 Mbps, LTE Cat4 150/50 Mbps, HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps, HSPA, LTE, HSPA, LTE Cat4 150/50 Mbps
# 13                                                                                                                                                                                                                                                             2018, March, 2016, August. Released 2016, October, 2016, August. Released 2016, December, 2016, April. Released 2016, June, 2015, April. Released 2016, February
# 14                                                                                                                                                                                                                                                                           Available. Released 2018, July, Discontinued, Available. Released 2022, May 31, Available. Released 2021, Q2, Available. Released 2021, October 22
# 15                                                                                                                                                                                      238.3 x 172.2 x 9.9 mm (9.38 x 6.78 x 0.39 in), 191.7 x 101 x 9.4 mm (7.55 x 3.98 x 0.37 in), 153.8 x 75.6 x 8.5 mm (6.06 x 2.98 x 0.33 in), 145.5 x 72.5 x 8.5 mm (5.73 x 2.85 x 0.33 in), 259 x 167 x 8.9 mm (10.20 x 6.57 x 0.35 in)
# 16                                                                                                                                                                                                                                                                                                                                                      544.3 g (1.20 lb), 260 g (9.17 oz), 169 g (5.96 oz), 126 g (4.44 oz), -
# 17                                                                                                                                                                                    nan, Glass front, plastic back, plastic frame, Glass front, plastic frame, plastic back, Glass front (DragonTrail Pro glass), plastic back, plastic frame, Glass front (Asahi Dragontrail), glass back (Asahi Dragontrail), plastic frame
# 18                                                                                                                                                                                                                               No, Dual SIM (Micro-SIM/Nano-SIM), Single SIM (Micro-SIM) or Hybrid Dual SIM (Micro-SIM, dual stand-by), Single SIM (Micro-SIM) or Dual SIM (Micro-SIM, dual stand-by), Triple SIM (Micro-SIM)
# 19                                                                                                                                                                                                                                                                                                                                                                      IPS LCD, Super AMOLED, AMOLED, LED-backlit IPS LCD, TFT
# 20                                                                                                                                                       9.7 inches, 291.4 cm2 (~71.0% screen-to-body ratio), 7.0 inches, 135.1 cm2 (~69.8% screen-to-body ratio), 5.5 inches, 83.4 cm2 (~71.7% screen-to-body ratio), 5.0 inches, 68.9 cm2 (~65.3% screen-to-body ratio), 10.1 inches, 295.8 cm2 (~68.4% screen-to-body ratio)
# 21                                                                                                                                                                  1536 x 2048 pixels, 4:3 ratio (~264 ppi density), 720 x 1280 pixels, 16:9 ratio (~210 ppi density), 1080 x 1920 pixels, 16:9 ratio (~401 ppi density), 720 x 1280 pixels, 16:9 ratio (~294 ppi density), 1920 x 1200 pixels, 16:10 ratio (~224 ppi density)
# 22                                                                                                                                                                                                                                                                              nan, Corning Gorilla Glass 4, Corning Gorilla Glass (unspecified version), Corning Gorilla Glass 4, oleophobic coating, Corning Gorilla Glass 3
# 23                                                                                                                                                                                                                                                                                                                   Chrome OS, Android 6.0 (Marshmallow), Android 5.1 (Lollipop), Android 5.0 (Lollipop), Microsoft Windows 10
# 24                                                                                                                                                                                                                                                                                                                         Rockchip RK3399, Mediatek MT8735, Mediatek MT6753 (28 nm), Mediatek MT6737 (28 nm), Mediatek MT8163A
# 25                                                                                                                                                                                                                                Hexa-core (4x Cortex-A53 & 2x Cortex-A72), Quad-core 1.3 GHz Cortex-A53, Octa-core 1.3 GHz Cortex-A53, Quad-core 1.25 GHz Cortex-A53, Hexa-core (4x1.4 GHz Cortex-A53 & 2x1.8 GHz Cortex-A57)
# 26                                                                                                                                                                                                                                                                                                                                                                 nan, Mali-T720MP2, Mali-T720MP3, Mali-T720 MP2, Mali-T720MP4
# 27                                                                                                                                                                                                                                                                                        microSDXC (dedicated slot), microSDXC (uses shared SIM slot), microSDXC, microSDHC (dedicated slot), microSDHC (uses shared SIM slot)
# 28                                                                                                                                                                                                                                                                                                                32GB 4GB RAM, 16GB 2GB RAM, 32GB 2GB RAM, 32GB 3GB RAM, 8GB 1GB RAM, 16GB 2GB RAM, 32GB 2GB RAM, 64GB 2GB RAM
# 29                                                                                                                                                                                                                                                                                                                                                                                                                         1, 0
# 30                                                                                                                                                                                                                                                                                                                                       nan, HDR, panorama, LED flash, HDR, panorama, LED flash, Dual-LED flash, HDR, panorama
# 31                                                                                                                                                                                                                                                                                                                                                       720p, 1080p@30fps, Yes, 4K@30fps, 1080p@30fps, 1080p@30fps, 720p@60fps
# 32                                                                                                                                                                                                                                                                                                                                                                                                                         1, 0
# 33                                                                                                                                                                                                                                                                                                                                             nan, LED flash, HDR, Dual-LED dual-tone flash, HDR, Cinematic mode (4K@24/30fps)
# 34                                                                                                                                                                                                                                                                                                                                                                                     nan, 720p, 1080p@30fps, 720p@30fps, 480p
# 35                                                                                                                                                                                                                                                                                                          Yes, with stereo speakers, Yes, Yes, with stereo speakers (4 speakers), Yes, dual speakers, Yes, with dual speakers
# 36                                                                                                                                                                                                                                                                                                                                                                    Yes, No, nan, No, included adaptor for 3.5mm, Unspecified
# 37                                                                                                                                                                                                                                                 Wi-Fi 802.11 b/g/n/ac, dual-band, Wi-Fi Direct, Wi-Fi 802.11 a/b/g/n, Wi-Fi Direct, Wi-Fi 802.11 b/g/n, Wi-Fi Direct, Wi-Fi 802.11 b/g/n, Wi-Fi 802.11 a/b/g/n/ac, dual-band
# 38                                                                                                                                                                                                                                                                                                                                                  4.1, A2DP, LE, 4.0, A2DP, 4.0, A2DP, LE, 4.0, A2DP, LE, EDR, 4.0, A2DP, EDR
# 39                                                                                                                                                                                                                                                                                                                                                                                       nan, GPS, GLONASS, GPS, A-GPS only, No
# 40                                                                                                                                                                                                                                                                                                                                                                   No, Yes, Yes (single sim model only), nan, Region specific
# 41                                                                                                                                                                                                                                                                                                                                                           No, FM radio, Stereo FM radio, RDS, Stereo FM radio, FM radio, RDS
# 42                                                                                                                                                                                                                                                                                                                           USB Type-C 3.1, microUSB 2.0, microUSB 2.0, OTG, microUSB 2.0, USB 2.0, OTG, microUSB 2.0, USB 2.0
# 43                                                                                                                                                                                                                                                   Accelerometer, Accelerometer, proximity, Fingerprint (front-mounted), accelerometer, proximity, Accelerometer, proximity, compass, Accelerometer, gyro, proximity, compass
# 44                                                                                                                                                                                                                                                  Li-Po 4500 mAh, non-removable (34 Wh), Li-Ion 3400 mAh, non-removable (12.92 Wh), Li-Po 4080 mAh, non-removable, Li-Ion 2000 mAh, removable, Li-Ion 6100 mAh, non-removable
# 45                                                                                                                                                                                                                                                                                                                                                           nan, Up to 820 h (3G), Up to 330 h (3G), Up to 430 h, Up to 1030 h
# 46                                                                                                                                                                                                                                                                                                                                              Up to 9 h (multimedia), nan, Up to 23 h (3G), Up to 8 h 30 min, Up to 20 h (3G)
# 47                                                                                                                                                                                                                                                                                                                                                                         nan, Up to 100 h, Up to 54 h, Up to 30 h, Up to 28 h
# 48                                                                                                                                                                                                                                                                                                                                                                   Black, Blue, Black, Black, White, Black, Gold, Blue, White
# 49                                                                                                                                                                                                                                          nan, 0.49 W/kg (head)     0.54 W/kg (body)     , 0.92 W/kg (head)     0.88 W/kg (body)     , 1.11 W/kg (head)     0.35 W/kg (body)     , 1.23 W/kg (head)     0.72 W/kg (body)
# 50                                                                                                                                                                                                                                                                                    nan, 0.62 W/kg (head)     , 0.44 W/kg (head)     0.41 W/kg (body)     , 0.23 W/kg (head)     , 0.38 W/kg (head)     0.70 W/kg (body)
# 51                                                                                                                                                                                                                                                                                                                                                                                            nan, GT-810-15NC, Z520, Z220, S56
# 52                                                                                                                                                                                                                                                                                                                                                    About 330 EUR, About 170 EUR, About 250 EUR, About 120 EUR, About 230 EUR

# %% [markdown]
# Nhận xét: trừ MAIN_CAM_1_Module, SELFIE_CAM_2_Module được xử lý sẵn trong lúc crawl, còn lại dữ liệu đề có dạng object (string)
